# %% [markdown]
# # PyTorch Computer Vision
#
# * See reference notebook - https://github.com/mrdbourke/pytorch-deep-learning/blob/main/03_pytorch_computer_vision.ipynb
# * See reference online book - https://www.learnpytorch.io/03_pytorch_computer_vision

# %% [markdown]
# ## 0. Computer vision libraries in PyTorch
#
# * `torchvision` - base domain library for PyTorch computer vision
# * `torchvision.datasets` - get datasets and data loading functions for computer vision here
# * `torchvision.models` - get pretrained computer vision models
# * `torchvision.transforms` - functions for manipulating your vision data (images) to be suitable for use with an ML model
# * `torch.utils.data.Dataset` - Base dataset class for PyTorch
# * `torch.utils.data.DataLoader` - Creates a Python iterable over a dataset

# %%
# Import PyTorch
import torch
from torch import nn

# Import torchvision
import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.transforms import ToTensor

# Import matplotlib for visualization
import matplotlib.pyplot as plt

# Check versions
print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.10.0+cu128
# 0.25.0+cu128

# %% [markdown]
# ## 1. Getting a dataset
#
# The data we'll be using is FashionMNIST from torchvision.datasets.

# %%
# Setup training data
from torchvision import datasets
train_data = datasets.FashionMNIST(
    root='data', # where to download data to?
    train=True, # do we want the training datasets
    download=True, # do we want to download yes/no?
    transform=torchvision.transforms.ToTensor(), # how do we want to transform the data?
    target_transform=None # how do we want to transform the labels/targets?
)

test_data = datasets.FashionMNIST(
    root='data',
    train=False,
    download=True,
    transform=ToTensor(),
    target_transform=None
)
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 12.8MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 197kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.77MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 15.4MB/s]

# %%
# Print the length of the training and testing data
print(f'Length of training data: {len(train_data)}')
print(f'Length of testing data: {len(test_data)}')
# Out:
# Length of training data: 60000
# Length of testing data: 10000

# %%
# See the first training example
image, label = train_data[0]
image, label
# Out:
# (tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0510,
#            0.2863, 0.0000, 0.0000, 0.0039, 0.0157, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0000, 0.1412, 0.5333,
#            0.4980, 0.2431, 0.2118, 0.0000, 0.0000, 0.0000, 0.0039, 0.0118,
#            0.0157, 0.0000, 0.0000, 0.0118],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0235, 0.0000, 0.4000, 0.8000,
#            0.6902, 0.5255, 0.5647, 0.4824, 0.0902, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0471, 0.0392, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6078, 0.9255,
#            0.8118, 0.6980, 0.4196, 0.6118, 0.6314, 0.4275, 0.2510, 0.0902,
#            0.3020, 0.5098, 0.2824, 0.0588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.2706, 0.8118, 0.8745,
#            0.8549, 0.8471, 0.8471, 0.6392, 0.4980, 0.4745, 0.4784, 0.5725,
#            0.5529, 0.3451, 0.6745, 0.2588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0039, 0.0000, 0.7843, 0.9098, 0.9098,
#            0.9137, 0.8980, 0.8745, 0.8745, 0.8431, 0.8353, 0.6431, 0.4980,
#            0.4824, 0.7686, 0.8980, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7176, 0.8824, 0.8471,
#            0.8745, 0.8941, 0.9216, 0.8902, 0.8784, 0.8706, 0.8784, 0.8667,
#            0.8745, 0.9608, 0.6784, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7569, 0.8941, 0.8549,
#            0.8353, 0.7765, 0.7059, 0.8314, 0.8235, 0.8275, 0.8353, 0.8745,
#            0.8627, 0.9529, 0.7922, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0118, 0.0000, 0.0471, 0.8588, 0.8627, 0.8314,
#            0.8549, 0.7529, 0.6627, 0.8902, 0.8157, 0.8549, 0.8784, 0.8314,
#            0.8863, 0.7725, 0.8196, 0.2039],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0235, 0.0000, 0.3882, 0.9569, 0.8706, 0.8627,
#            0.8549, 0.7961, 0.7765, 0.8667, 0.8431, 0.8353, 0.8706, 0.8627,
#            0.9608, 0.4667, 0.6549, 0.2196],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0157, 0.0000, 0.0000, 0.2157, 0.9255, 0.8941, 0.9020,
#            0.8941, 0.9412, 0.9098, 0.8353, 0.8549, 0.8745, 0.9176, 0.8510,
#            0.8510, 0.8196, 0.3608, 0.0000],
#           [0.0000, 0.0000, 0.0039, 0.0157, 0.0235, 0.0275, 0.0078, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.9294, 0.8863, 0.8510, 0.8745,
#            0.8706, 0.8588, 0.8706, 0.8667, 0.8471, 0.8745, 0.8980, 0.8431,
#            0.8549, 1.0000, 0.3020, 0.0000],
#           [0.0000, 0.0118, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.2431, 0.5686, 0.8000, 0.8941, 0.8118, 0.8353, 0.8667,
#            0.8549, 0.8157, 0.8275, 0.8549, 0.8784, 0.8745, 0.8588, 0.8431,
#            0.8784, 0.9569, 0.6235, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.1725, 0.3216, 0.4196,
#            0.7412, 0.8941, 0.8627, 0.8706, 0.8510, 0.8863, 0.7843, 0.8039,
#            0.8275, 0.9020, 0.8784, 0.9176, 0.6902, 0.7373, 0.9804, 0.9725,
#            0.9137, 0.9333, 0.8431, 0.0000],
#           [0.0000, 0.2235, 0.7333, 0.8157, 0.8784, 0.8667, 0.8784, 0.8157,
#            0.8000, 0.8392, 0.8157, 0.8196, 0.7843, 0.6235, 0.9608, 0.7569,
#            0.8078, 0.8745, 1.0000, 1.0000, 0.8667, 0.9176, 0.8667, 0.8275,
#            0.8627, 0.9098, 0.9647, 0.0000],
#           [0.0118, 0.7922, 0.8941, 0.8784, 0.8667, 0.8275, 0.8275, 0.8392,
#            0.8039, 0.8039, 0.8039, 0.8627, 0.9412, 0.3137, 0.5882, 1.0000,
#            0.8980, 0.8667, 0.7373, 0.6039, 0.7490, 0.8235, 0.8000, 0.8196,
#            0.8706, 0.8941, 0.8824, 0.0000],
#           [0.3843, 0.9137, 0.7765, 0.8235, 0.8706, 0.8980, 0.8980, 0.9176,
#            0.9765, 0.8627, 0.7608, 0.8431, 0.8510, 0.9451, 0.2549, 0.2863,
#            0.4157, 0.4588, 0.6588, 0.8588, 0.8667, 0.8431, 0.8510, 0.8745,
#            0.8745, 0.8784, 0.8980, 0.1137],
#           [0.2941, 0.8000, 0.8314, 0.8000, 0.7569, 0.8039, 0.8275, 0.8824,
#            0.8471, 0.7255, 0.7725, 0.8078, 0.7765, 0.8353, 0.9412, 0.7647,
#            0.8902, 0.9608, 0.9373, 0.8745, 0.8549, 0.8314, 0.8196, 0.8706,
#            0.8627, 0.8667, 0.9020, 0.2627],
#           [0.1882, 0.7961, 0.7176, 0.7608, 0.8353, 0.7725, 0.7255, 0.7451,
#            0.7608, 0.7529, 0.7922, 0.8392, 0.8588, 0.8667, 0.8627, 0.9255,
#            0.8824, 0.8471, 0.7804, 0.8078, 0.7294, 0.7098, 0.6941, 0.6745,
#            0.7098, 0.8039, 0.8078, 0.4510],
#           [0.0000, 0.4784, 0.8588, 0.7569, 0.7020, 0.6706, 0.7176, 0.7686,
#            0.8000, 0.8235, 0.8353, 0.8118, 0.8275, 0.8235, 0.7843, 0.7686,
#            0.7608, 0.7490, 0.7647, 0.7490, 0.7765, 0.7529, 0.6902, 0.6118,
#            0.6549, 0.6941, 0.8235, 0.3608],
#           [0.0000, 0.0000, 0.2902, 0.7412, 0.8314, 0.7490, 0.6863, 0.6745,
#            0.6863, 0.7098, 0.7255, 0.7373, 0.7412, 0.7373, 0.7569, 0.7765,
#            0.8000, 0.8196, 0.8235, 0.8235, 0.8275, 0.7373, 0.7373, 0.7608,
#            0.7529, 0.8471, 0.6667, 0.0000],
#           [0.0078, 0.0000, 0.0000, 0.0000, 0.2588, 0.7843, 0.8706, 0.9294,
#            0.9373, 0.9490, 0.9647, 0.9529, 0.9569, 0.8667, 0.8627, 0.7569,
#            0.7490, 0.7020, 0.7137, 0.7137, 0.7098, 0.6902, 0.6510, 0.6588,
#            0.3882, 0.2275, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1569,
#            0.2392, 0.1725, 0.2824, 0.1608, 0.1373, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000]]]),
#  9)

# %%
class_names = train_data.classes
class_names
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
# Obtain the classes of the training data and print
class_to_idx = train_data.class_to_idx
class_to_idx
# Out:
# {'T-shirt/top': 0,
#  'Trouser': 1,
#  'Pullover': 2,
#  'Dress': 3,
#  'Coat': 4,
#  'Sandal': 5,
#  'Shirt': 6,
#  'Sneaker': 7,
#  'Bag': 8,
#  'Ankle boot': 9}

# %% [markdown]
# ### 1.1 Check input and output shapes of data

# %%
# Check the shape of our image
print(f'Image shape: {image.shape} -> [color_channels, height, width]')
print(f'Image label: {class_names[label]}')
# Out:
# Image shape: torch.Size([1, 28, 28]) -> [color_channels, height, width]
# Image label: Ankle boot

# %% [markdown]
# ### 1.2 Visualizing out data

# %%
import matplotlib.pyplot as plt

# Display the first image in the training data
image, label = train_data[0]
print(f'Image shape: {image.shape}')
plt.imshow(image.squeeze())
plt.title(label)
plt.axis(False)
# Out:
# Image shape: torch.Size([1, 28, 28])
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))

# %%
# Display the class of the grayscaled image
plt.imshow(image.squeeze(), cmap='gray')
plt.title(class_names[label]);
plt.axis(False)
# Out:
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))

# %%
# Plot a range of images and their respective classes
# torch.manual_seed(42)
fig = plt.figure(figsize=(9, 9))
rows, cols = 4, 4
for i in range(1, rows*cols+1):
  random_idx = torch.randint(0, len(train_data), size=[1]).item()
  img, label = train_data[random_idx]
  fig.add_subplot(rows, cols, i)
  plt.imshow(img.squeeze(), cmap='gray')
  plt.title(class_names[label])
  plt.axis(False)

# %% [markdown]
# Do you think these items of clothing (images) could be modelled with pure linear lines? Or do you think we'll need non-linearities?

# %%
# Print information about the training and testing dataset
train_data, test_data
# Out:
# (Dataset FashionMNIST
#      Number of datapoints: 60000
#      Root location: data
#      Split: Train
#      StandardTransform
#  Transform: ToTensor(),
#  Dataset FashionMNIST
#      Number of datapoints: 10000
#      Root location: data
#      Split: Test
#      StandardTransform
#  Transform: ToTensor())

# %% [markdown]
# ## 2. Prepare DataLoader
#
# Right now, our data is in the form of PyTorch Datasets
#
# DataLoader turns our dataset into a Pytorch iterable.
#
# More specifically, we want to turn our data into batches (or mini-batches).
#
# Why would we do this?
#
# 1. It is more computationally efficient, as in, your computer hardware may not be able to look (store in memory) at 60000 images in one hit. So we break it down to 32 images at a time (batch size of 32).
# 2. It gives our neural network more chances to update its gradients per epoch.

# %%
from torch.utils.data import DataLoader

# Setup the batch size hyperparameter
BATCH_SIZE = 32

# Turn datasets into iterables (batches)
train_dataloader = DataLoader(dataset = train_data,
                              batch_size = BATCH_SIZE,
                              shuffle = True)

test_dataloader = DataLoader(dataset=test_data,
                             batch_size=BATCH_SIZE,
                             shuffle=False)

train_dataloader, test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7bb34657b6e0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7bb346592150>)

# %%
# Let's check out what we've created
print(f'DataLoaders: {train_dataloader, test_dataloader}')
print(f'Length of the train_dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}')
print(f'Length of test_dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}')
# Out:
# DataLoaders: (<torch.utils.data.dataloader.DataLoader object at 0x7bb34657b6e0>, <torch.utils.data.dataloader.DataLoader object at 0x7bb346592150>)
# Length of the train_dataloader: 1875 batches of 32
# Length of test_dataloader: 313 batches of 32

# %%
# Check out what's inside the training dataloader
train_features_batch, train_labels_batch = next(iter(train_dataloader))
train_features_batch.shape, train_labels_batch.shape
# Out:
# (torch.Size([32, 1, 28, 28]), torch.Size([32]))

# %%
# Display a random image in the training dataloader
# torch.manual_seed(42)
random_idx = torch.randint(0, len(train_features_batch), size=[1]).item()
img, label = train_features_batch[random_idx], train_labels_batch[random_idx]
plt.imshow(img.squeeze(), cmap='gray')
plt.title(class_names[label])
plt.axis('off')
print(f'Image size: {img.shape}')
print(f'Label: {label}, label size: {label.shape}')
# Out:
# Image size: torch.Size([1, 28, 28])
# Label: 0, label size: torch.Size([])

# %% [markdown]
# ## 3. Model 0: Build a baseline model
#
# When starting to build a series of machine learning modeling experiments, it's best practice to start with a baseline model.
#
# A baseline model is a simple model you will try and improve upon with subsequent models/experiments.
#
# In other words: start simply and add complexity when necessary

# %%
# Create a flatten layer
flatten_model = nn.Flatten()

# Get a single sample
x = train_features_batch[0]

# Flatten the sample
output = flatten_model(x) # perform forward pass

# Print out what happened:
print(f'Shape before flattening: {x.shape} -> [color_channels, height, width]')
print(f'Shape after flattening: {output.shape} -? [color_channels, height*width]')
# Out:
# Shape before flattening: torch.Size([1, 28, 28]) -> [color_channels, height, width]
# Shape after flattening: torch.Size([1, 784]) -? [color_channels, height*width]

# %%
from torch import nn
class FashionMNISTModelV0(nn.Module):
  def __init__(self,
               input_shape: int,
               hidden_units: int,
               output_shape: int):
    super().__init__()
    self.layer_stack = nn.Sequential(
        nn.Flatten(),
        nn.Linear(in_features=input_shape,
                  out_features=hidden_units),
        nn.Linear(in_features=hidden_units,
                  out_features=output_shape),
    )

  def forward(self, x):
    return self.layer_stack(x)

# %%
torch.manual_seed(42)

# Setup model with input parameters
model_0 = FashionMNISTModelV0(
    input_shape=784,
    hidden_units=10,
    output_shape=len(class_names),
).to('cpu')

model_0
# Out:
# FashionMNISTModelV0(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=784, out_features=10, bias=True)
#     (2): Linear(in_features=10, out_features=10, bias=True)
#   )
# )

# %%
# Pass a random set of inputs into the model
dummy_x = torch.rand([1, 1, 28, 28])
model_0(dummy_x)
# Out:
# tensor([[-0.0315,  0.3171,  0.0531, -0.2525,  0.5959,  0.2112,  0.3233,  0.2694,
#          -0.1004,  0.0157]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ### 3.1 Setup loss, optimizer, and evaluation metrics
#
# * Loss function - since we're working with multi-class data, our loss function will be `nn.CrossEntropyLoss()`
# * Optimizer -our optimizer `torch.optim.SGD()` (stochastic gradient descent)
# * Evaluation metric - since we're working on a classification problem, let's use accuruacy as our evaluation metric

# %%
import requests
from pathlib import Path

# Download helper functions from Learn PyTorch repo
if Path('helper_functions.py').is_file():
  print('helper_functions.py already exists, skipping download...')
else:
  print('Downloading helper_functions.py')
  request = requests.get('https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/helper_functions.py')
  with open('helper_functions.py', 'wb') as f:
    f.write(request.content)
# Out:
# helper_functions.py already exists, skipping download...

# %%
# Import accuracy metric
def accuracy_fn(y_true, y_pred):
    """Calculates accuracy between truth labels and predictions.

    Args:
        y_true (torch.Tensor): Truth labels for predictions.
        y_pred (torch.Tensor): Predictions to be compared to predictions.

    Returns:
        [torch.float]: Accuracy value between y_true and y_pred, e.g. 78.45
    """
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct / len(y_pred)) * 100
    return acc

# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=model_0.parameters(),
                            lr=0.1)

# %% [markdown]
# ### 3.2 Creating a function to time our experiments
#
# Machine learning is very experimental.
#
# Two of the main things you'll often want to track are:
# 1. Model's performance (loss and accuracy values etc)
# 2. How fast it runs

# %%
from timeit import default_timer as timer

# Define a function to print the training time
def print_train_time(start: float,
                     end: float,
                     device: torch.device = None):
  """Prints difference between start and end time."""
  total_time = end - start
  print(f'Train time on {device}: {total_time:.3f} seconds')
  return total_time

# %%
# Test out the training time function
start_time = timer()
end_time = timer()
print_train_time(start=start_time, end=end_time, device='cpu')
# Out:
# Train time on cpu: 0.000 seconds
# 0.00011769699995056726

# %% [markdown]
# ### 3.3 Creating a training loop and training a model on batches of data
#
# 1. Loop through epochs
# 2. Loop through training batches, perform training steps, calculate the train loss *per batch*.
# 3. Loop through testing batches, perform testing steps, calculate the test loss *per batch*.
# 4. Print out what's happening .
# 5. Time it all (for fun)

# %%
# Import tqdm for progress bar
from tqdm.auto import tqdm

# Set the seed and start the timer
torch.manual_seed(42)
train_time_start_on_cpu = timer()

# Set the number of epochs (we'll keep this small for faster training time)
epochs = 3

# Create training and test loop
for epoch in tqdm(range(epochs)):
  print(f'Epoch: {epoch}\n-----')
  ### Training
  train_loss = 0
  # Add a loop to loop through the training batches
  for batch, (X, y) in enumerate(train_dataloader):
    model_0.train()
    # 1. Forward pass
    y_pred = model_0(X)

    # 2. Calculate loss (per batch)
    loss = loss_fn(y_pred, y)
    train_loss += loss # accumulate train loss

    # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. Loss backward
    loss.backward()

    # 5. Optimizer step
    optimizer.step()

    # Print out what's happening
    if epoch % 4000 == 0:
      print(f'Looked at {batch * len(X)}/{len(train_dataloader.dataset)} samples')

  # Divide total train loss by length of train dataloader
  train_loss /= len(train_dataloader)

  ### Testing
  test_loss, test_acc = 0, 0
  model_0.eval()
  with torch.inference_mode():
    for X_test, y_test in test_dataloader:
      # 1. Forward Pass
      test_pred = model_0(X_test)

      # 2. Calculate loss (accumulatively)
      test_loss += loss_fn(test_pred, y_test)

      # 3. Calculate accuracy
      test_acc += accuracy_fn(y_true=y_test, y_pred=test_pred.argmax(dim=1))

    # Calculate the test loss average per batch
    test_loss /= len(test_dataloader)

    # Calculate the test acc average per batch
    test_acc /= len(test_dataloader)

  # Print out what's happening
  print(f'\nTrain loss: {train_loss:.4f} | Test loss: {test_loss:.4f}, Test acc: {test_acc:.4f}')

# Calculate training time
train_time_end_on_cpu = timer()
total_train_time_model_0 = print_train_time(start=train_time_start_on_cpu,
                                            end = train_time_end_on_cpu,
                                            device=str(next(model_0.parameters()).device))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# -----
# Looked at 0/60000 samples
# Looked at 32/60000 samples
# Looked at 64/60000 samples
# Looked at 96/60000 samples
# Looked at 128/60000 samples
# Looked at 160/60000 samples
# Looked at 192/60000 samples
# Looked at 224/60000 samples
# Looked at 256/60000 samples
# Looked at 288/60000 samples
# Looked at 320/60000 samples
# Looked at 352/60000 samples
# Looked at 384/60000 samples
# Looked at 416/60000 samples
# Looked at 448/60000 samples
# Looked at 480/60000 samples
# Looked at 512/60000 samples
# Looked at 544/60000 samples
# Looked at 576/60000 samples
# Looked at 608/60000 samples
# Looked at 640/60000 samples
# Looked at 672/60000 samples
# Looked at 704/60000 samples
# Looked at 736/60000 samples
# Looked at 768/60000 samples
# Looked at 800/60000 samples
# Looked at 832/60000 samples
# Looked at 864/60000 samples
# Looked at 896/60000 samples
# Looked at 928/60000 samples
# Looked at 960/60000 samples
# Looked at 992/60000 samples
# Looked at 1024/60000 samples
# Looked at 1056/60000 samples
# Looked at 1088/60000 samples
# Looked at 1120/60000 samples
# Looked at 1152/60000 samples
# Looked at 1184/60000 samples
# Looked at 1216/60000 samples
# Looked at 1248/60000 samples
# Looked at 1280/60000 samples
# Looked at 1312/60000 samples
# Looked at 1344/60000 samples
# Looked at 1376/60000 samples
# Looked at 1408/60000 samples
# Looked at 1440/60000 samples
# Looked at 1472/60000 samples
# Looked at 1504/60000 samples
# Looked at 1536/60000 samples
# Looked at 1568/60000 samples
# Looked at 1600/60000 samples
# Looked at 1632/60000 samples
# Looked at 1664/60000 samples
# Looked at 1696/60000 samples
# Looked at 1728/60000 samples
# Looked at 1760/60000 samples
# Looked at 1792/60000 samples
# Looked at 1824/60000 samples
# Looked at 1856/60000 samples
# Looked at 1888/60000 samples
# Looked at 1920/60000 samples
# Looked at 1952/60000 samples
# Looked at 1984/60000 samples
# Looked at 2016/60000 samples
# Looked at 2048/60000 samples
# Looked at 2080/60000 samples
# Looked at 2112/60000 samples
# Looked at 2144/60000 samples
# Looked at 2176/60000 samples
# Looked at 2208/60000 samples
# Looked at 2240/60000 samples
# Looked at 2272/60000 samples
# Looked at 2304/60000 samples
# Looked at 2336/60000 samples
# Looked at 2368/60000 samples
# Looked at 2400/60000 samples
# Looked at 2432/60000 samples
# Looked at 2464/60000 samples
# Looked at 2496/60000 samples
# Looked at 2528/60000 samples
# Looked at 2560/60000 samples
# Looked at 2592/60000 samples
# Looked at 2624/60000 samples
# Looked at 2656/60000 samples
# Looked at 2688/60000 samples
# Looked at 2720/60000 samples
# Looked at 2752/60000 samples
# Looked at 2784/60000 samples
# Looked at 2816/60000 samples
# Looked at 2848/60000 samples
# Looked at 2880/60000 samples
# Looked at 2912/60000 samples
# Looked at 2944/60000 samples
# Looked at 2976/60000 samples
# Looked at 3008/60000 samples
# Looked at 3040/60000 samples
# Looked at 3072/60000 samples
# Looked at 3104/60000 samples
# Looked at 3136/60000 samples
# Looked at 3168/60000 samples
# Looked at 3200/60000 samples
# Looked at 3232/60000 samples
# Looked at 3264/60000 samples
# Looked at 3296/60000 samples
# Looked at 3328/60000 samples
# Looked at 3360/60000 samples
# Looked at 3392/60000 samples
# Looked at 3424/60000 samples
# Looked at 3456/60000 samples
# Looked at 3488/60000 samples
# Looked at 3520/60000 samples
# Looked at 3552/60000 samples
# Looked at 3584/60000 samples
# Looked at 3616/60000 samples
# Looked at 3648/60000 samples
# Looked at 3680/60000 samples
# Looked at 3712/60000 samples
# Looked at 3744/60000 samples
# Looked at 3776/60000 samples
# Looked at 3808/60000 samples
# Looked at 3840/60000 samples
# Looked at 3872/60000 samples
# Looked at 3904/60000 samples
# Looked at 3936/60000 samples
# Looked at 3968/60000 samples
# Looked at 4000/60000 samples
# Looked at 4032/60000 samples
# Looked at 4064/60000 samples
# Looked at 4096/60000 samples
# Looked at 4128/60000 samples
# Looked at 4160/60000 samples
# Looked at 4192/60000 samples
# Looked at 4224/60000 samples
# Looked at 4256/60000 samples
# Looked at 4288/60000 samples
# Looked at 4320/60000 samples
# Looked at 4352/60000 samples
# Looked at 4384/60000 samples
# Looked at 4416/60000 samples
# Looked at 4448/60000 samples
# Looked at 4480/60000 samples
# Looked at 4512/60000 samples
# Looked at 4544/60000 samples
# Looked at 4576/60000 samples
# Looked at 4608/60000 samples
# Looked at 4640/60000 samples
# Looked at 4672/60000 samples
# Looked at 4704/60000 samples
# Looked at 4736/60000 samples
# Looked at 4768/60000 samples
# Looked at 4800/60000 samples
# Looked at 4832/60000 samples
# Looked at 4864/60000 samples
# Looked at 4896/60000 samples
# Looked at 4928/60000 samples
# Looked at 4960/60000 samples
# Looked at 4992/60000 samples
# Looked at 5024/60000 samples
# Looked at 5056/60000 samples
# Looked at 5088/60000 samples
# Looked at 5120/60000 samples
# Looked at 5152/60000 samples
# Looked at 5184/60000 samples
# Looked at 5216/60000 samples
# Looked at 5248/60000 samples
# Looked at 5280/60000 samples
# Looked at 5312/60000 samples
# Looked at 5344/60000 samples
# Looked at 5376/60000 samples
# Looked at 5408/60000 samples
# Looked at 5440/60000 samples
# Looked at 5472/60000 samples
# Looked at 5504/60000 samples
# Looked at 5536/60000 samples
# Looked at 5568/60000 samples
# Looked at 5600/60000 samples
# Looked at 5632/60000 samples
# Looked at 5664/60000 samples
# Looked at 5696/60000 samples
# Looked at 5728/60000 samples
# Looked at 5760/60000 samples
# Looked at 5792/60000 samples
# Looked at 5824/60000 samples
# Looked at 5856/60000 samples
# Looked at 5888/60000 samples
# Looked at 5920/60000 samples
# Looked at 5952/60000 samples
# Looked at 5984/60000 samples
# Looked at 6016/60000 samples
# Looked at 6048/60000 samples
# Looked at 6080/60000 samples
# Looked at 6112/60000 samples
# Looked at 6144/60000 samples
# Looked at 6176/60000 samples
# Looked at 6208/60000 samples
# Looked at 6240/60000 samples
# Looked at 6272/60000 samples
# Looked at 6304/60000 samples
# Looked at 6336/60000 samples
# Looked at 6368/60000 samples
# Looked at 6400/60000 samples
# Looked at 6432/60000 samples
# Looked at 6464/60000 samples
# Looked at 6496/60000 samples
# Looked at 6528/60000 samples
# Looked at 6560/60000 samples
# Looked at 6592/60000 samples
# Looked at 6624/60000 samples
# Looked at 6656/60000 samples
# Looked at 6688/60000 samples
# Looked at 6720/60000 samples
# Looked at 6752/60000 samples
# Looked at 6784/60000 samples
# Looked at 6816/60000 samples
# Looked at 6848/60000 samples
# Looked at 6880/60000 samples
# Looked at 6912/60000 samples
# Looked at 6944/60000 samples
# Looked at 6976/60000 samples
# Looked at 7008/60000 samples
# Looked at 7040/60000 samples
# Looked at 7072/60000 samples
# Looked at 7104/60000 samples
# Looked at 7136/60000 samples
# Looked at 7168/60000 samples
# Looked at 7200/60000 samples
# Looked at 7232/60000 samples
# Looked at 7264/60000 samples
# Looked at 7296/60000 samples
# Looked at 7328/60000 samples
# Looked at 7360/60000 samples
# Looked at 7392/60000 samples
# Looked at 7424/60000 samples
# Looked at 7456/60000 samples
# Looked at 7488/60000 samples
# Looked at 7520/60000 samples
# Looked at 7552/60000 samples
# Looked at 7584/60000 samples
# Looked at 7616/60000 samples
# Looked at 7648/60000 samples
# Looked at 7680/60000 samples
# Looked at 7712/60000 samples
# Looked at 7744/60000 samples
# Looked at 7776/60000 samples
# Looked at 7808/60000 samples
# Looked at 7840/60000 samples
# Looked at 7872/60000 samples
# Looked at 7904/60000 samples
# Looked at 7936/60000 samples
# Looked at 7968/60000 samples
# Looked at 8000/60000 samples
# Looked at 8032/60000 samples
# Looked at 8064/60000 samples
# Looked at 8096/60000 samples
# Looked at 8128/60000 samples
# Looked at 8160/60000 samples
# Looked at 8192/60000 samples
# Looked at 8224/60000 samples
# Looked at 8256/60000 samples
# Looked at 8288/60000 samples
# Looked at 8320/60000 samples
# Looked at 8352/60000 samples
# Looked at 8384/60000 samples
# Looked at 8416/60000 samples
# Looked at 8448/60000 samples
# Looked at 8480/60000 samples
# Looked at 8512/60000 samples
# Looked at 8544/60000 samples
# Looked at 8576/60000 samples
# Looked at 8608/60000 samples
# Looked at 8640/60000 samples
# Looked at 8672/60000 samples
# Looked at 8704/60000 samples
# Looked at 8736/60000 samples
# Looked at 8768/60000 samples
# Looked at 8800/60000 samples
# Looked at 8832/60000 samples
# Looked at 8864/60000 samples
# Looked at 8896/60000 samples
# Looked at 8928/60000 samples
# Looked at 8960/60000 samples
# Looked at 8992/60000 samples
# Looked at 9024/60000 samples
# Looked at 9056/60000 samples
# Looked at 9088/60000 samples
# Looked at 9120/60000 samples
# Looked at 9152/60000 samples
# Looked at 9184/60000 samples
# Looked at 9216/60000 samples
# Looked at 9248/60000 samples
# Looked at 9280/60000 samples
# Looked at 9312/60000 samples
# Looked at 9344/60000 samples
# Looked at 9376/60000 samples
# Looked at 9408/60000 samples
# Looked at 9440/60000 samples
# Looked at 9472/60000 samples
# Looked at 9504/60000 samples
# Looked at 9536/60000 samples
# Looked at 9568/60000 samples
# Looked at 9600/60000 samples
# Looked at 9632/60000 samples
# Looked at 9664/60000 samples
# Looked at 9696/60000 samples
# Looked at 9728/60000 samples
# Looked at 9760/60000 samples
# Looked at 9792/60000 samples
# Looked at 9824/60000 samples
# Looked at 9856/60000 samples
# Looked at 9888/60000 samples
# Looked at 9920/60000 samples
# Looked at 9952/60000 samples
# Looked at 9984/60000 samples
# Looked at 10016/60000 samples
# Looked at 10048/60000 samples
# Looked at 10080/60000 samples
# Looked at 10112/60000 samples
# Looked at 10144/60000 samples
# Looked at 10176/60000 samples
# Looked at 10208/60000 samples
# Looked at 10240/60000 samples
# Looked at 10272/60000 samples
# Looked at 10304/60000 samples
# Looked at 10336/60000 samples
# Looked at 10368/60000 samples
# Looked at 10400/60000 samples
# Looked at 10432/60000 samples
# Looked at 10464/60000 samples
# Looked at 10496/60000 samples
# Looked at 10528/60000 samples
# Looked at 10560/60000 samples
# Looked at 10592/60000 samples
# Looked at 10624/60000 samples
# Looked at 10656/60000 samples
# Looked at 10688/60000 samples
# Looked at 10720/60000 samples
# Looked at 10752/60000 samples
# Looked at 10784/60000 samples
# Looked at 10816/60000 samples
# Looked at 10848/60000 samples
# Looked at 10880/60000 samples
# Looked at 10912/60000 samples
# Looked at 10944/60000 samples
# Looked at 10976/60000 samples
# Looked at 11008/60000 samples
# Looked at 11040/60000 samples
# Looked at 11072/60000 samples
# Looked at 11104/60000 samples
# Looked at 11136/60000 samples
# Looked at 11168/60000 samples
# Looked at 11200/60000 samples
# Looked at 11232/60000 samples
# Looked at 11264/60000 samples
# Looked at 11296/60000 samples
# Looked at 11328/60000 samples
# Looked at 11360/60000 samples
# Looked at 11392/60000 samples
# Looked at 11424/60000 samples
# Looked at 11456/60000 samples
# Looked at 11488/60000 samples
# Looked at 11520/60000 samples
# Looked at 11552/60000 samples
# Looked at 11584/60000 samples
# Looked at 11616/60000 samples
# Looked at 11648/60000 samples
# Looked at 11680/60000 samples
# Looked at 11712/60000 samples
# Looked at 11744/60000 samples
# Looked at 11776/60000 samples
# Looked at 11808/60000 samples
# Looked at 11840/60000 samples
# Looked at 11872/60000 samples
# Looked at 11904/60000 samples
# Looked at 11936/60000 samples
# Looked at 11968/60000 samples
# Looked at 12000/60000 samples
# Looked at 12032/60000 samples
# Looked at 12064/60000 samples
# Looked at 12096/60000 samples
# Looked at 12128/60000 samples
# Looked at 12160/60000 samples
# Looked at 12192/60000 samples
# Looked at 12224/60000 samples
# Looked at 12256/60000 samples
# Looked at 12288/60000 samples
# Looked at 12320/60000 samples
# Looked at 12352/60000 samples
# Looked at 12384/60000 samples
# Looked at 12416/60000 samples
# Looked at 12448/60000 samples
# Looked at 12480/60000 samples
# Looked at 12512/60000 samples
# Looked at 12544/60000 samples
# Looked at 12576/60000 samples
# Looked at 12608/60000 samples
# Looked at 12640/60000 samples
# Looked at 12672/60000 samples
# Looked at 12704/60000 samples
# Looked at 12736/60000 samples
# Looked at 12768/60000 samples
# Looked at 12800/60000 samples
# Looked at 12832/60000 samples
# Looked at 12864/60000 samples
# Looked at 12896/60000 samples
# Looked at 12928/60000 samples
# Looked at 12960/60000 samples
# Looked at 12992/60000 samples
# Looked at 13024/60000 samples
# Looked at 13056/60000 samples
# Looked at 13088/60000 samples
# Looked at 13120/60000 samples
# Looked at 13152/60000 samples
# Looked at 13184/60000 samples
# Looked at 13216/60000 samples
# Looked at 13248/60000 samples
# Looked at 13280/60000 samples
# Looked at 13312/60000 samples
# Looked at 13344/60000 samples
# Looked at 13376/60000 samples
# Looked at 13408/60000 samples
# Looked at 13440/60000 samples
# Looked at 13472/60000 samples
# Looked at 13504/60000 samples
# Looked at 13536/60000 samples
# Looked at 13568/60000 samples
# Looked at 13600/60000 samples
# Looked at 13632/60000 samples
# Looked at 13664/60000 samples
# Looked at 13696/60000 samples
# Looked at 13728/60000 samples
# Looked at 13760/60000 samples
# Looked at 13792/60000 samples
# Looked at 13824/60000 samples
# Looked at 13856/60000 samples
# Looked at 13888/60000 samples
# Looked at 13920/60000 samples
# Looked at 13952/60000 samples
# Looked at 13984/60000 samples
# Looked at 14016/60000 samples
# Looked at 14048/60000 samples
# Looked at 14080/60000 samples
# Looked at 14112/60000 samples
# Looked at 14144/60000 samples
# Looked at 14176/60000 samples
# Looked at 14208/60000 samples
# Looked at 14240/60000 samples
# Looked at 14272/60000 samples
# Looked at 14304/60000 samples
# Looked at 14336/60000 samples
# Looked at 14368/60000 samples
# Looked at 14400/60000 samples
# Looked at 14432/60000 samples
# Looked at 14464/60000 samples
# Looked at 14496/60000 samples
# Looked at 14528/60000 samples
# Looked at 14560/60000 samples
# Looked at 14592/60000 samples
# Looked at 14624/60000 samples
# Looked at 14656/60000 samples
# Looked at 14688/60000 samples
# Looked at 14720/60000 samples
# Looked at 14752/60000 samples
# Looked at 14784/60000 samples
# Looked at 14816/60000 samples
# Looked at 14848/60000 samples
# Looked at 14880/60000 samples
# Looked at 14912/60000 samples
# Looked at 14944/60000 samples
# Looked at 14976/60000 samples
# Looked at 15008/60000 samples
# Looked at 15040/60000 samples
# Looked at 15072/60000 samples
# Looked at 15104/60000 samples
# Looked at 15136/60000 samples
# Looked at 15168/60000 samples
# Looked at 15200/60000 samples
# Looked at 15232/60000 samples
# Looked at 15264/60000 samples
# Looked at 15296/60000 samples
# Looked at 15328/60000 samples
# Looked at 15360/60000 samples
# Looked at 15392/60000 samples
# Looked at 15424/60000 samples
# Looked at 15456/60000 samples
# Looked at 15488/60000 samples
# Looked at 15520/60000 samples
# Looked at 15552/60000 samples
# Looked at 15584/60000 samples
# Looked at 15616/60000 samples
# Looked at 15648/60000 samples
# Looked at 15680/60000 samples
# Looked at 15712/60000 samples
# Looked at 15744/60000 samples
# Looked at 15776/60000 samples
# Looked at 15808/60000 samples
# Looked at 15840/60000 samples
# Looked at 15872/60000 samples
# Looked at 15904/60000 samples
# Looked at 15936/60000 samples
# Looked at 15968/60000 samples
# Looked at 16000/60000 samples
# Looked at 16032/60000 samples
# Looked at 16064/60000 samples
# Looked at 16096/60000 samples
# Looked at 16128/60000 samples
# Looked at 16160/60000 samples
# Looked at 16192/60000 samples
# Looked at 16224/60000 samples
# Looked at 16256/60000 samples
# Looked at 16288/60000 samples
# Looked at 16320/60000 samples
# Looked at 16352/60000 samples
# Looked at 16384/60000 samples
# Looked at 16416/60000 samples
# Looked at 16448/60000 samples
# Looked at 16480/60000 samples
# Looked at 16512/60000 samples
# Looked at 16544/60000 samples
# Looked at 16576/60000 samples
# Looked at 16608/60000 samples
# Looked at 16640/60000 samples
# Looked at 16672/60000 samples
# Looked at 16704/60000 samples
# Looked at 16736/60000 samples
# Looked at 16768/60000 samples
# Looked at 16800/60000 samples
# Looked at 16832/60000 samples
# Looked at 16864/60000 samples
# Looked at 16896/60000 samples
# Looked at 16928/60000 samples
# Looked at 16960/60000 samples
# Looked at 16992/60000 samples
# Looked at 17024/60000 samples
# Looked at 17056/60000 samples
# Looked at 17088/60000 samples
# Looked at 17120/60000 samples
# Looked at 17152/60000 samples
# Looked at 17184/60000 samples
# Looked at 17216/60000 samples
# Looked at 17248/60000 samples
# Looked at 17280/60000 samples
# Looked at 17312/60000 samples
# Looked at 17344/60000 samples
# Looked at 17376/60000 samples
# Looked at 17408/60000 samples
# Looked at 17440/60000 samples
# Looked at 17472/60000 samples
# Looked at 17504/60000 samples
# Looked at 17536/60000 samples
# Looked at 17568/60000 samples
# Looked at 17600/60000 samples
# Looked at 17632/60000 samples
# Looked at 17664/60000 samples
# Looked at 17696/60000 samples
# Looked at 17728/60000 samples
# Looked at 17760/60000 samples
# Looked at 17792/60000 samples
# Looked at 17824/60000 samples
# Looked at 17856/60000 samples
# Looked at 17888/60000 samples
# Looked at 17920/60000 samples
# Looked at 17952/60000 samples
# Looked at 17984/60000 samples
# Looked at 18016/60000 samples
# Looked at 18048/60000 samples
# Looked at 18080/60000 samples
# Looked at 18112/60000 samples
# Looked at 18144/60000 samples
# Looked at 18176/60000 samples
# Looked at 18208/60000 samples
# Looked at 18240/60000 samples
# Looked at 18272/60000 samples
# Looked at 18304/60000 samples
# Looked at 18336/60000 samples
# Looked at 18368/60000 samples
# Looked at 18400/60000 samples
# Looked at 18432/60000 samples
# Looked at 18464/60000 samples
# Looked at 18496/60000 samples
# Looked at 18528/60000 samples
# Looked at 18560/60000 samples
# Looked at 18592/60000 samples
# Looked at 18624/60000 samples
# Looked at 18656/60000 samples
# Looked at 18688/60000 samples
# Looked at 18720/60000 samples
# Looked at 18752/60000 samples
# Looked at 18784/60000 samples
# Looked at 18816/60000 samples
# Looked at 18848/60000 samples
# Looked at 18880/60000 samples
# Looked at 18912/60000 samples
# Looked at 18944/60000 samples
# Looked at 18976/60000 samples
# Looked at 19008/60000 samples
# Looked at 19040/60000 samples
# Looked at 19072/60000 samples
# Looked at 19104/60000 samples
# Looked at 19136/60000 samples
# Looked at 19168/60000 samples
# Looked at 19200/60000 samples
# Looked at 19232/60000 samples
# Looked at 19264/60000 samples
# Looked at 19296/60000 samples
# Looked at 19328/60000 samples
# Looked at 19360/60000 samples
# Looked at 19392/60000 samples
# Looked at 19424/60000 samples
# Looked at 19456/60000 samples
# Looked at 19488/60000 samples
# Looked at 19520/60000 samples
# Looked at 19552/60000 samples
# Looked at 19584/60000 samples
# Looked at 19616/60000 samples
# Looked at 19648/60000 samples
# Looked at 19680/60000 samples
# Looked at 19712/60000 samples
# Looked at 19744/60000 samples
# Looked at 19776/60000 samples
# Looked at 19808/60000 samples
# Looked at 19840/60000 samples
# Looked at 19872/60000 samples
# Looked at 19904/60000 samples
# Looked at 19936/60000 samples
# Looked at 19968/60000 samples
# Looked at 20000/60000 samples
# Looked at 20032/60000 samples
# Looked at 20064/60000 samples
# Looked at 20096/60000 samples
# Looked at 20128/60000 samples
# Looked at 20160/60000 samples
# Looked at 20192/60000 samples
# Looked at 20224/60000 samples
# Looked at 20256/60000 samples
# Looked at 20288/60000 samples
# Looked at 20320/60000 samples
# Looked at 20352/60000 samples
# Looked at 20384/60000 samples
# Looked at 20416/60000 samples
# Looked at 20448/60000 samples
# Looked at 20480/60000 samples
# Looked at 20512/60000 samples
# Looked at 20544/60000 samples
# Looked at 20576/60000 samples
# Looked at 20608/60000 samples
# Looked at 20640/60000 samples
# Looked at 20672/60000 samples
# Looked at 20704/60000 samples
# Looked at 20736/60000 samples
# Looked at 20768/60000 samples
# Looked at 20800/60000 samples
# Looked at 20832/60000 samples
# Looked at 20864/60000 samples
# Looked at 20896/60000 samples
# Looked at 20928/60000 samples
# Looked at 20960/60000 samples
# Looked at 20992/60000 samples
# Looked at 21024/60000 samples
# Looked at 21056/60000 samples
# Looked at 21088/60000 samples
# Looked at 21120/60000 samples
# Looked at 21152/60000 samples
# Looked at 21184/60000 samples
# Looked at 21216/60000 samples
# Looked at 21248/60000 samples
# Looked at 21280/60000 samples
# Looked at 21312/60000 samples
# Looked at 21344/60000 samples
# Looked at 21376/60000 samples
# Looked at 21408/60000 samples
# Looked at 21440/60000 samples
# Looked at 21472/60000 samples
# Looked at 21504/60000 samples
# Looked at 21536/60000 samples
# Looked at 21568/60000 samples
# Looked at 21600/60000 samples
# Looked at 21632/60000 samples
# Looked at 21664/60000 samples
# Looked at 21696/60000 samples
# Looked at 21728/60000 samples
# Looked at 21760/60000 samples
# Looked at 21792/60000 samples
# Looked at 21824/60000 samples
# Looked at 21856/60000 samples
# Looked at 21888/60000 samples
# Looked at 21920/60000 samples
# Looked at 21952/60000 samples
# Looked at 21984/60000 samples
# Looked at 22016/60000 samples
# Looked at 22048/60000 samples
# Looked at 22080/60000 samples
# Looked at 22112/60000 samples
# Looked at 22144/60000 samples
# Looked at 22176/60000 samples
# Looked at 22208/60000 samples
# Looked at 22240/60000 samples
# Looked at 22272/60000 samples
# Looked at 22304/60000 samples
# Looked at 22336/60000 samples
# Looked at 22368/60000 samples
# Looked at 22400/60000 samples
# Looked at 22432/60000 samples
# Looked at 22464/60000 samples
# Looked at 22496/60000 samples
# Looked at 22528/60000 samples
# Looked at 22560/60000 samples
# Looked at 22592/60000 samples
# Looked at 22624/60000 samples
# Looked at 22656/60000 samples
# Looked at 22688/60000 samples
# Looked at 22720/60000 samples
# Looked at 22752/60000 samples
# Looked at 22784/60000 samples
# Looked at 22816/60000 samples
# Looked at 22848/60000 samples
# Looked at 22880/60000 samples
# Looked at 22912/60000 samples
# Looked at 22944/60000 samples
# Looked at 22976/60000 samples
# Looked at 23008/60000 samples
# Looked at 23040/60000 samples
# Looked at 23072/60000 samples
# Looked at 23104/60000 samples
# Looked at 23136/60000 samples
# Looked at 23168/60000 samples
# Looked at 23200/60000 samples
# Looked at 23232/60000 samples
# Looked at 23264/60000 samples
# Looked at 23296/60000 samples
# Looked at 23328/60000 samples
# Looked at 23360/60000 samples
# Looked at 23392/60000 samples
# Looked at 23424/60000 samples
# Looked at 23456/60000 samples
# Looked at 23488/60000 samples
# Looked at 23520/60000 samples
# Looked at 23552/60000 samples
# Looked at 23584/60000 samples
# Looked at 23616/60000 samples
# Looked at 23648/60000 samples
# Looked at 23680/60000 samples
# Looked at 23712/60000 samples
# Looked at 23744/60000 samples
# Looked at 23776/60000 samples
# Looked at 23808/60000 samples
# Looked at 23840/60000 samples
# Looked at 23872/60000 samples
# Looked at 23904/60000 samples
# Looked at 23936/60000 samples
# Looked at 23968/60000 samples
# Looked at 24000/60000 samples
# Looked at 24032/60000 samples
# Looked at 24064/60000 samples
# Looked at 24096/60000 samples
# Looked at 24128/60000 samples
# Looked at 24160/60000 samples
# Looked at 24192/60000 samples
# Looked at 24224/60000 samples
# Looked at 24256/60000 samples
# Looked at 24288/60000 samples
# Looked at 24320/60000 samples
# Looked at 24352/60000 samples
# Looked at 24384/60000 samples
# Looked at 24416/60000 samples
# Looked at 24448/60000 samples
# Looked at 24480/60000 samples
# Looked at 24512/60000 samples
# Looked at 24544/60000 samples
# Looked at 24576/60000 samples
# Looked at 24608/60000 samples
# Looked at 24640/60000 samples
# Looked at 24672/60000 samples
# Looked at 24704/60000 samples
# Looked at 24736/60000 samples
# Looked at 24768/60000 samples
# Looked at 24800/60000 samples
# Looked at 24832/60000 samples
# Looked at 24864/60000 samples
# Looked at 24896/60000 samples
# Looked at 24928/60000 samples
# Looked at 24960/60000 samples
# Looked at 24992/60000 samples
# Looked at 25024/60000 samples
# Looked at 25056/60000 samples
# Looked at 25088/60000 samples
# Looked at 25120/60000 samples
# Looked at 25152/60000 samples
# Looked at 25184/60000 samples
# Looked at 25216/60000 samples
# Looked at 25248/60000 samples
# Looked at 25280/60000 samples
# Looked at 25312/60000 samples
# Looked at 25344/60000 samples
# Looked at 25376/60000 samples
# Looked at 25408/60000 samples
# Looked at 25440/60000 samples
# Looked at 25472/60000 samples
# Looked at 25504/60000 samples
# Looked at 25536/60000 samples
# Looked at 25568/60000 samples
# Looked at 25600/60000 samples
# Looked at 25632/60000 samples
# Looked at 25664/60000 samples
# Looked at 25696/60000 samples
# Looked at 25728/60000 samples
# Looked at 25760/60000 samples
# Looked at 25792/60000 samples
# Looked at 25824/60000 samples
# Looked at 25856/60000 samples
# Looked at 25888/60000 samples
# Looked at 25920/60000 samples
# Looked at 25952/60000 samples
# Looked at 25984/60000 samples
# Looked at 26016/60000 samples
# Looked at 26048/60000 samples
# Looked at 26080/60000 samples
# Looked at 26112/60000 samples
# Looked at 26144/60000 samples
# Looked at 26176/60000 samples
# Looked at 26208/60000 samples
# Looked at 26240/60000 samples
# Looked at 26272/60000 samples
# Looked at 26304/60000 samples
# Looked at 26336/60000 samples
# Looked at 26368/60000 samples
# Looked at 26400/60000 samples
# Looked at 26432/60000 samples
# Looked at 26464/60000 samples
# Looked at 26496/60000 samples
# Looked at 26528/60000 samples
# Looked at 26560/60000 samples
# Looked at 26592/60000 samples
# Looked at 26624/60000 samples
# Looked at 26656/60000 samples
# Looked at 26688/60000 samples
# Looked at 26720/60000 samples
# Looked at 26752/60000 samples
# Looked at 26784/60000 samples
# Looked at 26816/60000 samples
# Looked at 26848/60000 samples
# Looked at 26880/60000 samples
# Looked at 26912/60000 samples
# Looked at 26944/60000 samples
# Looked at 26976/60000 samples
# Looked at 27008/60000 samples
# Looked at 27040/60000 samples
# Looked at 27072/60000 samples
# Looked at 27104/60000 samples
# Looked at 27136/60000 samples
# Looked at 27168/60000 samples
# Looked at 27200/60000 samples
# Looked at 27232/60000 samples
# Looked at 27264/60000 samples
# Looked at 27296/60000 samples
# Looked at 27328/60000 samples
# Looked at 27360/60000 samples
# Looked at 27392/60000 samples
# Looked at 27424/60000 samples
# Looked at 27456/60000 samples
# Looked at 27488/60000 samples
# Looked at 27520/60000 samples
# Looked at 27552/60000 samples
# Looked at 27584/60000 samples
# Looked at 27616/60000 samples
# Looked at 27648/60000 samples
# Looked at 27680/60000 samples
# Looked at 27712/60000 samples
# Looked at 27744/60000 samples
# Looked at 27776/60000 samples
# Looked at 27808/60000 samples
# Looked at 27840/60000 samples
# Looked at 27872/60000 samples
# Looked at 27904/60000 samples
# Looked at 27936/60000 samples
# Looked at 27968/60000 samples
# Looked at 28000/60000 samples
# Looked at 28032/60000 samples
# Looked at 28064/60000 samples
# Looked at 28096/60000 samples
# Looked at 28128/60000 samples
# Looked at 28160/60000 samples
# Looked at 28192/60000 samples
# Looked at 28224/60000 samples
# Looked at 28256/60000 samples
# Looked at 28288/60000 samples
# Looked at 28320/60000 samples
# Looked at 28352/60000 samples
# Looked at 28384/60000 samples
# Looked at 28416/60000 samples
# Looked at 28448/60000 samples
# Looked at 28480/60000 samples
# Looked at 28512/60000 samples
# Looked at 28544/60000 samples
# Looked at 28576/60000 samples
# Looked at 28608/60000 samples
# Looked at 28640/60000 samples
# Looked at 28672/60000 samples
# Looked at 28704/60000 samples
# Looked at 28736/60000 samples
# Looked at 28768/60000 samples
# Looked at 28800/60000 samples
# Looked at 28832/60000 samples
# Looked at 28864/60000 samples
# Looked at 28896/60000 samples
# Looked at 28928/60000 samples
# Looked at 28960/60000 samples
# Looked at 28992/60000 samples
# Looked at 29024/60000 samples
# Looked at 29056/60000 samples
# Looked at 29088/60000 samples
# Looked at 29120/60000 samples
# Looked at 29152/60000 samples
# Looked at 29184/60000 samples
# Looked at 29216/60000 samples
# Looked at 29248/60000 samples
# Looked at 29280/60000 samples
# Looked at 29312/60000 samples
# Looked at 29344/60000 samples
# Looked at 29376/60000 samples
# Looked at 29408/60000 samples
# Looked at 29440/60000 samples
# Looked at 29472/60000 samples
# Looked at 29504/60000 samples
# Looked at 29536/60000 samples
# Looked at 29568/60000 samples
# Looked at 29600/60000 samples
# Looked at 29632/60000 samples
# Looked at 29664/60000 samples
# Looked at 29696/60000 samples
# Looked at 29728/60000 samples
# Looked at 29760/60000 samples
# Looked at 29792/60000 samples
# Looked at 29824/60000 samples
# Looked at 29856/60000 samples
# Looked at 29888/60000 samples
# Looked at 29920/60000 samples
# Looked at 29952/60000 samples
# Looked at 29984/60000 samples
# Looked at 30016/60000 samples
# Looked at 30048/60000 samples
# Looked at 30080/60000 samples
# Looked at 30112/60000 samples
# Looked at 30144/60000 samples
# Looked at 30176/60000 samples
# Looked at 30208/60000 samples
# Looked at 30240/60000 samples
# Looked at 30272/60000 samples
# Looked at 30304/60000 samples
# Looked at 30336/60000 samples
# Looked at 30368/60000 samples
# Looked at 30400/60000 samples
# Looked at 30432/60000 samples
# Looked at 30464/60000 samples
# Looked at 30496/60000 samples
# Looked at 30528/60000 samples
# Looked at 30560/60000 samples
# Looked at 30592/60000 samples
# Looked at 30624/60000 samples
# Looked at 30656/60000 samples
# Looked at 30688/60000 samples
# Looked at 30720/60000 samples
# Looked at 30752/60000 samples
# Looked at 30784/60000 samples
# Looked at 30816/60000 samples
# Looked at 30848/60000 samples
# Looked at 30880/60000 samples
# Looked at 30912/60000 samples
# Looked at 30944/60000 samples
# Looked at 30976/60000 samples
# Looked at 31008/60000 samples
# Looked at 31040/60000 samples
# Looked at 31072/60000 samples
# Looked at 31104/60000 samples
# Looked at 31136/60000 samples
# Looked at 31168/60000 samples
# Looked at 31200/60000 samples
# Looked at 31232/60000 samples
# Looked at 31264/60000 samples
# Looked at 31296/60000 samples
# Looked at 31328/60000 samples
# Looked at 31360/60000 samples
# Looked at 31392/60000 samples
# Looked at 31424/60000 samples
# Looked at 31456/60000 samples
# Looked at 31488/60000 samples
# Looked at 31520/60000 samples
# Looked at 31552/60000 samples
# Looked at 31584/60000 samples
# Looked at 31616/60000 samples
# Looked at 31648/60000 samples
# Looked at 31680/60000 samples
# Looked at 31712/60000 samples
# Looked at 31744/60000 samples
# Looked at 31776/60000 samples
# Looked at 31808/60000 samples
# Looked at 31840/60000 samples
# Looked at 31872/60000 samples
# Looked at 31904/60000 samples
# Looked at 31936/60000 samples
# Looked at 31968/60000 samples
# Looked at 32000/60000 samples
# Looked at 32032/60000 samples
# Looked at 32064/60000 samples
# Looked at 32096/60000 samples
# Looked at 32128/60000 samples
# Looked at 32160/60000 samples
# Looked at 32192/60000 samples
# Looked at 32224/60000 samples
# Looked at 32256/60000 samples
# Looked at 32288/60000 samples
# Looked at 32320/60000 samples
# Looked at 32352/60000 samples
# Looked at 32384/60000 samples
# Looked at 32416/60000 samples
# Looked at 32448/60000 samples
# Looked at 32480/60000 samples
# Looked at 32512/60000 samples
# Looked at 32544/60000 samples
# Looked at 32576/60000 samples
# Looked at 32608/60000 samples
# Looked at 32640/60000 samples
# Looked at 32672/60000 samples
# Looked at 32704/60000 samples
# Looked at 32736/60000 samples
# Looked at 32768/60000 samples
# Looked at 32800/60000 samples
# Looked at 32832/60000 samples
# Looked at 32864/60000 samples
# Looked at 32896/60000 samples
# Looked at 32928/60000 samples
# Looked at 32960/60000 samples
# Looked at 32992/60000 samples
# Looked at 33024/60000 samples
# Looked at 33056/60000 samples
# Looked at 33088/60000 samples
# Looked at 33120/60000 samples
# Looked at 33152/60000 samples
# Looked at 33184/60000 samples
# Looked at 33216/60000 samples
# Looked at 33248/60000 samples
# Looked at 33280/60000 samples
# Looked at 33312/60000 samples
# Looked at 33344/60000 samples
# Looked at 33376/60000 samples
# Looked at 33408/60000 samples
# Looked at 33440/60000 samples
# Looked at 33472/60000 samples
# Looked at 33504/60000 samples
# Looked at 33536/60000 samples
# Looked at 33568/60000 samples
# Looked at 33600/60000 samples
# Looked at 33632/60000 samples
# Looked at 33664/60000 samples
# Looked at 33696/60000 samples
# Looked at 33728/60000 samples
# Looked at 33760/60000 samples
# Looked at 33792/60000 samples
# Looked at 33824/60000 samples
# Looked at 33856/60000 samples
# Looked at 33888/60000 samples
# Looked at 33920/60000 samples
# Looked at 33952/60000 samples
# Looked at 33984/60000 samples
# Looked at 34016/60000 samples
# Looked at 34048/60000 samples
# Looked at 34080/60000 samples
# Looked at 34112/60000 samples
# Looked at 34144/60000 samples
# Looked at 34176/60000 samples
# Looked at 34208/60000 samples
# Looked at 34240/60000 samples
# Looked at 34272/60000 samples
# Looked at 34304/60000 samples
# Looked at 34336/60000 samples
# Looked at 34368/60000 samples
# Looked at 34400/60000 samples
# Looked at 34432/60000 samples
# Looked at 34464/60000 samples
# Looked at 34496/60000 samples
# Looked at 34528/60000 samples
# Looked at 34560/60000 samples
# Looked at 34592/60000 samples
# Looked at 34624/60000 samples
# Looked at 34656/60000 samples
# Looked at 34688/60000 samples
# Looked at 34720/60000 samples
# Looked at 34752/60000 samples
# Looked at 34784/60000 samples
# Looked at 34816/60000 samples
# Looked at 34848/60000 samples
# Looked at 34880/60000 samples
# Looked at 34912/60000 samples
# Looked at 34944/60000 samples
# Looked at 34976/60000 samples
# Looked at 35008/60000 samples
# Looked at 35040/60000 samples
# Looked at 35072/60000 samples
# Looked at 35104/60000 samples
# Looked at 35136/60000 samples
# Looked at 35168/60000 samples
# Looked at 35200/60000 samples
# Looked at 35232/60000 samples
# Looked at 35264/60000 samples
# Looked at 35296/60000 samples
# Looked at 35328/60000 samples
# Looked at 35360/60000 samples
# Looked at 35392/60000 samples
# Looked at 35424/60000 samples
# Looked at 35456/60000 samples
# Looked at 35488/60000 samples
# Looked at 35520/60000 samples
# Looked at 35552/60000 samples
# Looked at 35584/60000 samples
# Looked at 35616/60000 samples
# Looked at 35648/60000 samples
# Looked at 35680/60000 samples
# Looked at 35712/60000 samples
# Looked at 35744/60000 samples
# Looked at 35776/60000 samples
# Looked at 35808/60000 samples
# Looked at 35840/60000 samples
# Looked at 35872/60000 samples
# Looked at 35904/60000 samples
# Looked at 35936/60000 samples
# Looked at 35968/60000 samples
# Looked at 36000/60000 samples
# Looked at 36032/60000 samples
# Looked at 36064/60000 samples
# Looked at 36096/60000 samples
# Looked at 36128/60000 samples
# Looked at 36160/60000 samples
# Looked at 36192/60000 samples
# Looked at 36224/60000 samples
# Looked at 36256/60000 samples
# Looked at 36288/60000 samples
# Looked at 36320/60000 samples
# Looked at 36352/60000 samples
# Looked at 36384/60000 samples
# Looked at 36416/60000 samples
# Looked at 36448/60000 samples
# Looked at 36480/60000 samples
# Looked at 36512/60000 samples
# Looked at 36544/60000 samples
# Looked at 36576/60000 samples
# Looked at 36608/60000 samples
# Looked at 36640/60000 samples
# Looked at 36672/60000 samples
# Looked at 36704/60000 samples
# Looked at 36736/60000 samples
# Looked at 36768/60000 samples
# Looked at 36800/60000 samples
# Looked at 36832/60000 samples
# Looked at 36864/60000 samples
# Looked at 36896/60000 samples
# Looked at 36928/60000 samples
# Looked at 36960/60000 samples
# Looked at 36992/60000 samples
# Looked at 37024/60000 samples
# Looked at 37056/60000 samples
# Looked at 37088/60000 samples
# Looked at 37120/60000 samples
# Looked at 37152/60000 samples
# Looked at 37184/60000 samples
# Looked at 37216/60000 samples
# Looked at 37248/60000 samples
# Looked at 37280/60000 samples
# Looked at 37312/60000 samples
# Looked at 37344/60000 samples
# Looked at 37376/60000 samples
# Looked at 37408/60000 samples
# Looked at 37440/60000 samples
# Looked at 37472/60000 samples
# Looked at 37504/60000 samples
# Looked at 37536/60000 samples
# Looked at 37568/60000 samples
# Looked at 37600/60000 samples
# Looked at 37632/60000 samples
# Looked at 37664/60000 samples
# Looked at 37696/60000 samples
# Looked at 37728/60000 samples
# Looked at 37760/60000 samples
# Looked at 37792/60000 samples
# Looked at 37824/60000 samples
# Looked at 37856/60000 samples
# Looked at 37888/60000 samples
# Looked at 37920/60000 samples
# Looked at 37952/60000 samples
# Looked at 37984/60000 samples
# Looked at 38016/60000 samples
# Looked at 38048/60000 samples
# Looked at 38080/60000 samples
# Looked at 38112/60000 samples
# Looked at 38144/60000 samples
# Looked at 38176/60000 samples
# Looked at 38208/60000 samples
# Looked at 38240/60000 samples
# Looked at 38272/60000 samples
# Looked at 38304/60000 samples
# Looked at 38336/60000 samples
# Looked at 38368/60000 samples
# Looked at 38400/60000 samples
# Looked at 38432/60000 samples
# Looked at 38464/60000 samples
# Looked at 38496/60000 samples
# Looked at 38528/60000 samples
# Looked at 38560/60000 samples
# Looked at 38592/60000 samples
# Looked at 38624/60000 samples
# Looked at 38656/60000 samples
# Looked at 38688/60000 samples
# Looked at 38720/60000 samples
# Looked at 38752/60000 samples
# Looked at 38784/60000 samples
# Looked at 38816/60000 samples
# Looked at 38848/60000 samples
# Looked at 38880/60000 samples
# Looked at 38912/60000 samples
# Looked at 38944/60000 samples
# Looked at 38976/60000 samples
# Looked at 39008/60000 samples
# Looked at 39040/60000 samples
# Looked at 39072/60000 samples
# Looked at 39104/60000 samples
# Looked at 39136/60000 samples
# Looked at 39168/60000 samples
# Looked at 39200/60000 samples
# Looked at 39232/60000 samples
# Looked at 39264/60000 samples
# Looked at 39296/60000 samples
# Looked at 39328/60000 samples
# Looked at 39360/60000 samples
# Looked at 39392/60000 samples
# Looked at 39424/60000 samples
# Looked at 39456/60000 samples
# Looked at 39488/60000 samples
# Looked at 39520/60000 samples
# Looked at 39552/60000 samples
# Looked at 39584/60000 samples
# Looked at 39616/60000 samples
# Looked at 39648/60000 samples
# Looked at 39680/60000 samples
# Looked at 39712/60000 samples
# Looked at 39744/60000 samples
# Looked at 39776/60000 samples
# Looked at 39808/60000 samples
# Looked at 39840/60000 samples
# Looked at 39872/60000 samples
# Looked at 39904/60000 samples
# Looked at 39936/60000 samples
# Looked at 39968/60000 samples
# Looked at 40000/60000 samples
# Looked at 40032/60000 samples
# Looked at 40064/60000 samples
# Looked at 40096/60000 samples
# Looked at 40128/60000 samples
# Looked at 40160/60000 samples
# Looked at 40192/60000 samples
# Looked at 40224/60000 samples
# Looked at 40256/60000 samples
# Looked at 40288/60000 samples
# Looked at 40320/60000 samples
# Looked at 40352/60000 samples
# Looked at 40384/60000 samples
# Looked at 40416/60000 samples
# Looked at 40448/60000 samples
# Looked at 40480/60000 samples
# Looked at 40512/60000 samples
# Looked at 40544/60000 samples
# Looked at 40576/60000 samples
# Looked at 40608/60000 samples
# Looked at 40640/60000 samples
# Looked at 40672/60000 samples
# Looked at 40704/60000 samples
# Looked at 40736/60000 samples
# Looked at 40768/60000 samples
# Looked at 40800/60000 samples
# Looked at 40832/60000 samples
# Looked at 40864/60000 samples
# Looked at 40896/60000 samples
# Looked at 40928/60000 samples
# Looked at 40960/60000 samples
# Looked at 40992/60000 samples
# Looked at 41024/60000 samples
# Looked at 41056/60000 samples
# Looked at 41088/60000 samples
# Looked at 41120/60000 samples
# Looked at 41152/60000 samples
# Looked at 41184/60000 samples
# Looked at 41216/60000 samples
# Looked at 41248/60000 samples
# Looked at 41280/60000 samples
# Looked at 41312/60000 samples
# Looked at 41344/60000 samples
# Looked at 41376/60000 samples
# Looked at 41408/60000 samples
# Looked at 41440/60000 samples
# Looked at 41472/60000 samples
# Looked at 41504/60000 samples
# Looked at 41536/60000 samples
# Looked at 41568/60000 samples
# Looked at 41600/60000 samples
# Looked at 41632/60000 samples
# Looked at 41664/60000 samples
# Looked at 41696/60000 samples
# Looked at 41728/60000 samples
# Looked at 41760/60000 samples
# Looked at 41792/60000 samples
# Looked at 41824/60000 samples
# Looked at 41856/60000 samples
# Looked at 41888/60000 samples
# Looked at 41920/60000 samples
# Looked at 41952/60000 samples
# Looked at 41984/60000 samples
# Looked at 42016/60000 samples
# Looked at 42048/60000 samples
# Looked at 42080/60000 samples
# Looked at 42112/60000 samples
# Looked at 42144/60000 samples
# Looked at 42176/60000 samples
# Looked at 42208/60000 samples
# Looked at 42240/60000 samples
# Looked at 42272/60000 samples
# Looked at 42304/60000 samples
# Looked at 42336/60000 samples
# Looked at 42368/60000 samples
# Looked at 42400/60000 samples
# Looked at 42432/60000 samples
# Looked at 42464/60000 samples
# Looked at 42496/60000 samples
# Looked at 42528/60000 samples
# Looked at 42560/60000 samples
# Looked at 42592/60000 samples
# Looked at 42624/60000 samples
# Looked at 42656/60000 samples
# Looked at 42688/60000 samples
# Looked at 42720/60000 samples
# Looked at 42752/60000 samples
# Looked at 42784/60000 samples
# Looked at 42816/60000 samples
# Looked at 42848/60000 samples
# Looked at 42880/60000 samples
# Looked at 42912/60000 samples
# Looked at 42944/60000 samples
# Looked at 42976/60000 samples
# Looked at 43008/60000 samples
# Looked at 43040/60000 samples
# Looked at 43072/60000 samples
# Looked at 43104/60000 samples
# Looked at 43136/60000 samples
# Looked at 43168/60000 samples
# Looked at 43200/60000 samples
# Looked at 43232/60000 samples
# Looked at 43264/60000 samples
# Looked at 43296/60000 samples
# Looked at 43328/60000 samples
# Looked at 43360/60000 samples
# Looked at 43392/60000 samples
# Looked at 43424/60000 samples
# Looked at 43456/60000 samples
# Looked at 43488/60000 samples
# Looked at 43520/60000 samples
# Looked at 43552/60000 samples
# Looked at 43584/60000 samples
# Looked at 43616/60000 samples
# Looked at 43648/60000 samples
# Looked at 43680/60000 samples
# Looked at 43712/60000 samples
# Looked at 43744/60000 samples
# Looked at 43776/60000 samples
# Looked at 43808/60000 samples
# Looked at 43840/60000 samples
# Looked at 43872/60000 samples
# Looked at 43904/60000 samples
# Looked at 43936/60000 samples
# Looked at 43968/60000 samples
# Looked at 44000/60000 samples
# Looked at 44032/60000 samples
# Looked at 44064/60000 samples
# Looked at 44096/60000 samples
# Looked at 44128/60000 samples
# Looked at 44160/60000 samples
# Looked at 44192/60000 samples
# Looked at 44224/60000 samples
# Looked at 44256/60000 samples
# Looked at 44288/60000 samples
# Looked at 44320/60000 samples
# Looked at 44352/60000 samples
# Looked at 44384/60000 samples
# Looked at 44416/60000 samples
# Looked at 44448/60000 samples
# Looked at 44480/60000 samples
# Looked at 44512/60000 samples
# Looked at 44544/60000 samples
# Looked at 44576/60000 samples
# Looked at 44608/60000 samples
# Looked at 44640/60000 samples
# Looked at 44672/60000 samples
# Looked at 44704/60000 samples
# Looked at 44736/60000 samples
# Looked at 44768/60000 samples
# Looked at 44800/60000 samples
# Looked at 44832/60000 samples
# Looked at 44864/60000 samples
# Looked at 44896/60000 samples
# Looked at 44928/60000 samples
# Looked at 44960/60000 samples
# Looked at 44992/60000 samples
# Looked at 45024/60000 samples
# Looked at 45056/60000 samples
# Looked at 45088/60000 samples
# Looked at 45120/60000 samples
# Looked at 45152/60000 samples
# Looked at 45184/60000 samples
# Looked at 45216/60000 samples
# Looked at 45248/60000 samples
# Looked at 45280/60000 samples
# Looked at 45312/60000 samples
# Looked at 45344/60000 samples
# Looked at 45376/60000 samples
# Looked at 45408/60000 samples
# Looked at 45440/60000 samples
# Looked at 45472/60000 samples
# Looked at 45504/60000 samples
# Looked at 45536/60000 samples
# Looked at 45568/60000 samples
# Looked at 45600/60000 samples
# Looked at 45632/60000 samples
# Looked at 45664/60000 samples
# Looked at 45696/60000 samples
# Looked at 45728/60000 samples
# Looked at 45760/60000 samples
# Looked at 45792/60000 samples
# Looked at 45824/60000 samples
# Looked at 45856/60000 samples
# Looked at 45888/60000 samples
# Looked at 45920/60000 samples
# Looked at 45952/60000 samples
# Looked at 45984/60000 samples
# Looked at 46016/60000 samples
# Looked at 46048/60000 samples
# Looked at 46080/60000 samples
# Looked at 46112/60000 samples
# Looked at 46144/60000 samples
# Looked at 46176/60000 samples
# Looked at 46208/60000 samples
# Looked at 46240/60000 samples
# Looked at 46272/60000 samples
# Looked at 46304/60000 samples
# Looked at 46336/60000 samples
# Looked at 46368/60000 samples
# Looked at 46400/60000 samples
# Looked at 46432/60000 samples
# Looked at 46464/60000 samples
# Looked at 46496/60000 samples
# Looked at 46528/60000 samples
# Looked at 46560/60000 samples
# Looked at 46592/60000 samples
# Looked at 46624/60000 samples
# Looked at 46656/60000 samples
# Looked at 46688/60000 samples
# Looked at 46720/60000 samples
# Looked at 46752/60000 samples
# Looked at 46784/60000 samples
# Looked at 46816/60000 samples
# Looked at 46848/60000 samples
# Looked at 46880/60000 samples
# Looked at 46912/60000 samples
# Looked at 46944/60000 samples
# Looked at 46976/60000 samples
# Looked at 47008/60000 samples
# Looked at 47040/60000 samples
# Looked at 47072/60000 samples
# Looked at 47104/60000 samples
# Looked at 47136/60000 samples
# Looked at 47168/60000 samples
# Looked at 47200/60000 samples
# Looked at 47232/60000 samples
# Looked at 47264/60000 samples
# Looked at 47296/60000 samples
# Looked at 47328/60000 samples
# Looked at 47360/60000 samples
# Looked at 47392/60000 samples
# Looked at 47424/60000 samples
# Looked at 47456/60000 samples
# Looked at 47488/60000 samples
# Looked at 47520/60000 samples
# Looked at 47552/60000 samples
# Looked at 47584/60000 samples
# Looked at 47616/60000 samples
# Looked at 47648/60000 samples
# Looked at 47680/60000 samples
# Looked at 47712/60000 samples
# Looked at 47744/60000 samples
# Looked at 47776/60000 samples
# Looked at 47808/60000 samples
# Looked at 47840/60000 samples
# Looked at 47872/60000 samples
# Looked at 47904/60000 samples
# Looked at 47936/60000 samples
# Looked at 47968/60000 samples
# Looked at 48000/60000 samples
# Looked at 48032/60000 samples
# Looked at 48064/60000 samples
# Looked at 48096/60000 samples
# Looked at 48128/60000 samples
# Looked at 48160/60000 samples
# Looked at 48192/60000 samples
# Looked at 48224/60000 samples
# Looked at 48256/60000 samples
# Looked at 48288/60000 samples
# Looked at 48320/60000 samples
# Looked at 48352/60000 samples
# Looked at 48384/60000 samples
# Looked at 48416/60000 samples
# Looked at 48448/60000 samples
# Looked at 48480/60000 samples
# Looked at 48512/60000 samples
# Looked at 48544/60000 samples
# Looked at 48576/60000 samples
# Looked at 48608/60000 samples
# Looked at 48640/60000 samples
# Looked at 48672/60000 samples
# Looked at 48704/60000 samples
# Looked at 48736/60000 samples
# Looked at 48768/60000 samples
# Looked at 48800/60000 samples
# Looked at 48832/60000 samples
# Looked at 48864/60000 samples
# Looked at 48896/60000 samples
# Looked at 48928/60000 samples
# Looked at 48960/60000 samples
# Looked at 48992/60000 samples
# Looked at 49024/60000 samples
# Looked at 49056/60000 samples
# Looked at 49088/60000 samples
# Looked at 49120/60000 samples
# Looked at 49152/60000 samples
# Looked at 49184/60000 samples
# Looked at 49216/60000 samples
# Looked at 49248/60000 samples
# Looked at 49280/60000 samples
# Looked at 49312/60000 samples
# Looked at 49344/60000 samples
# Looked at 49376/60000 samples
# Looked at 49408/60000 samples
# Looked at 49440/60000 samples
# Looked at 49472/60000 samples
# Looked at 49504/60000 samples
# Looked at 49536/60000 samples
# Looked at 49568/60000 samples
# Looked at 49600/60000 samples
# Looked at 49632/60000 samples
# Looked at 49664/60000 samples
# Looked at 49696/60000 samples
# Looked at 49728/60000 samples
# Looked at 49760/60000 samples
# Looked at 49792/60000 samples
# Looked at 49824/60000 samples
# Looked at 49856/60000 samples
# Looked at 49888/60000 samples
# Looked at 49920/60000 samples
# Looked at 49952/60000 samples
# Looked at 49984/60000 samples
# Looked at 50016/60000 samples
# Looked at 50048/60000 samples
# Looked at 50080/60000 samples
# Looked at 50112/60000 samples
# Looked at 50144/60000 samples
# Looked at 50176/60000 samples
# Looked at 50208/60000 samples
# Looked at 50240/60000 samples
# Looked at 50272/60000 samples
# Looked at 50304/60000 samples
# Looked at 50336/60000 samples
# Looked at 50368/60000 samples
# Looked at 50400/60000 samples
# Looked at 50432/60000 samples
# Looked at 50464/60000 samples
# Looked at 50496/60000 samples
# Looked at 50528/60000 samples
# Looked at 50560/60000 samples
# Looked at 50592/60000 samples
# Looked at 50624/60000 samples
# Looked at 50656/60000 samples
# Looked at 50688/60000 samples
# Looked at 50720/60000 samples
# Looked at 50752/60000 samples
# Looked at 50784/60000 samples
# Looked at 50816/60000 samples
# Looked at 50848/60000 samples
# Looked at 50880/60000 samples
# Looked at 50912/60000 samples
# Looked at 50944/60000 samples
# Looked at 50976/60000 samples
# Looked at 51008/60000 samples
# Looked at 51040/60000 samples
# Looked at 51072/60000 samples
# Looked at 51104/60000 samples
# Looked at 51136/60000 samples
# Looked at 51168/60000 samples
# Looked at 51200/60000 samples
# Looked at 51232/60000 samples
# Looked at 51264/60000 samples
# Looked at 51296/60000 samples
# Looked at 51328/60000 samples
# Looked at 51360/60000 samples
# Looked at 51392/60000 samples
# Looked at 51424/60000 samples
# Looked at 51456/60000 samples
# Looked at 51488/60000 samples
# Looked at 51520/60000 samples
# Looked at 51552/60000 samples
# Looked at 51584/60000 samples
# Looked at 51616/60000 samples
# Looked at 51648/60000 samples
# Looked at 51680/60000 samples
# Looked at 51712/60000 samples
# Looked at 51744/60000 samples
# Looked at 51776/60000 samples
# Looked at 51808/60000 samples
# Looked at 51840/60000 samples
# Looked at 51872/60000 samples
# Looked at 51904/60000 samples
# Looked at 51936/60000 samples
# Looked at 51968/60000 samples
# Looked at 52000/60000 samples
# Looked at 52032/60000 samples
# Looked at 52064/60000 samples
# Looked at 52096/60000 samples
# Looked at 52128/60000 samples
# Looked at 52160/60000 samples
# Looked at 52192/60000 samples
# Looked at 52224/60000 samples
# Looked at 52256/60000 samples
# Looked at 52288/60000 samples
# Looked at 52320/60000 samples
# Looked at 52352/60000 samples
# Looked at 52384/60000 samples
# Looked at 52416/60000 samples
# Looked at 52448/60000 samples
# Looked at 52480/60000 samples
# Looked at 52512/60000 samples
# Looked at 52544/60000 samples
# Looked at 52576/60000 samples
# Looked at 52608/60000 samples
# Looked at 52640/60000 samples
# Looked at 52672/60000 samples
# Looked at 52704/60000 samples
# Looked at 52736/60000 samples
# Looked at 52768/60000 samples
# Looked at 52800/60000 samples
# Looked at 52832/60000 samples
# Looked at 52864/60000 samples
# Looked at 52896/60000 samples
# Looked at 52928/60000 samples
# Looked at 52960/60000 samples
# Looked at 52992/60000 samples
# Looked at 53024/60000 samples
# Looked at 53056/60000 samples
# Looked at 53088/60000 samples
# Looked at 53120/60000 samples
# Looked at 53152/60000 samples
# Looked at 53184/60000 samples
# Looked at 53216/60000 samples
# Looked at 53248/60000 samples
# Looked at 53280/60000 samples
# Looked at 53312/60000 samples
# Looked at 53344/60000 samples
# Looked at 53376/60000 samples
# Looked at 53408/60000 samples
# Looked at 53440/60000 samples
# Looked at 53472/60000 samples
# Looked at 53504/60000 samples
# Looked at 53536/60000 samples
# Looked at 53568/60000 samples
# Looked at 53600/60000 samples
# Looked at 53632/60000 samples
# Looked at 53664/60000 samples
# Looked at 53696/60000 samples
# Looked at 53728/60000 samples
# Looked at 53760/60000 samples
# Looked at 53792/60000 samples
# Looked at 53824/60000 samples
# Looked at 53856/60000 samples
# Looked at 53888/60000 samples
# Looked at 53920/60000 samples
# Looked at 53952/60000 samples
# Looked at 53984/60000 samples
# Looked at 54016/60000 samples
# Looked at 54048/60000 samples
# Looked at 54080/60000 samples
# Looked at 54112/60000 samples
# Looked at 54144/60000 samples
# Looked at 54176/60000 samples
# Looked at 54208/60000 samples
# Looked at 54240/60000 samples
# Looked at 54272/60000 samples
# Looked at 54304/60000 samples
# Looked at 54336/60000 samples
# Looked at 54368/60000 samples
# Looked at 54400/60000 samples
# Looked at 54432/60000 samples
# Looked at 54464/60000 samples
# Looked at 54496/60000 samples
# Looked at 54528/60000 samples
# Looked at 54560/60000 samples
# Looked at 54592/60000 samples
# Looked at 54624/60000 samples
# Looked at 54656/60000 samples
# Looked at 54688/60000 samples
# Looked at 54720/60000 samples
# Looked at 54752/60000 samples
# Looked at 54784/60000 samples
# Looked at 54816/60000 samples
# Looked at 54848/60000 samples
# Looked at 54880/60000 samples
# Looked at 54912/60000 samples
# Looked at 54944/60000 samples
# Looked at 54976/60000 samples
# Looked at 55008/60000 samples
# Looked at 55040/60000 samples
# Looked at 55072/60000 samples
# Looked at 55104/60000 samples
# Looked at 55136/60000 samples
# Looked at 55168/60000 samples
# Looked at 55200/60000 samples
# Looked at 55232/60000 samples
# Looked at 55264/60000 samples
# Looked at 55296/60000 samples
# Looked at 55328/60000 samples
# Looked at 55360/60000 samples
# Looked at 55392/60000 samples
# Looked at 55424/60000 samples
# Looked at 55456/60000 samples
# Looked at 55488/60000 samples
# Looked at 55520/60000 samples
# Looked at 55552/60000 samples
# Looked at 55584/60000 samples
# Looked at 55616/60000 samples
# Looked at 55648/60000 samples
# Looked at 55680/60000 samples
# Looked at 55712/60000 samples
# Looked at 55744/60000 samples
# Looked at 55776/60000 samples
# Looked at 55808/60000 samples
# Looked at 55840/60000 samples
# Looked at 55872/60000 samples
# Looked at 55904/60000 samples
# Looked at 55936/60000 samples
# Looked at 55968/60000 samples
# Looked at 56000/60000 samples
# Looked at 56032/60000 samples
# Looked at 56064/60000 samples
# Looked at 56096/60000 samples
# Looked at 56128/60000 samples
# Looked at 56160/60000 samples
# Looked at 56192/60000 samples
# Looked at 56224/60000 samples
# Looked at 56256/60000 samples
# Looked at 56288/60000 samples
# Looked at 56320/60000 samples
# Looked at 56352/60000 samples
# Looked at 56384/60000 samples
# Looked at 56416/60000 samples
# Looked at 56448/60000 samples
# Looked at 56480/60000 samples
# Looked at 56512/60000 samples
# Looked at 56544/60000 samples
# Looked at 56576/60000 samples
# Looked at 56608/60000 samples
# Looked at 56640/60000 samples
# Looked at 56672/60000 samples
# Looked at 56704/60000 samples
# Looked at 56736/60000 samples
# Looked at 56768/60000 samples
# Looked at 56800/60000 samples
# Looked at 56832/60000 samples
# Looked at 56864/60000 samples
# Looked at 56896/60000 samples
# Looked at 56928/60000 samples
# Looked at 56960/60000 samples
# Looked at 56992/60000 samples
# Looked at 57024/60000 samples
# Looked at 57056/60000 samples
# Looked at 57088/60000 samples
# Looked at 57120/60000 samples
# Looked at 57152/60000 samples
# Looked at 57184/60000 samples
# Looked at 57216/60000 samples
# Looked at 57248/60000 samples
# Looked at 57280/60000 samples
# Looked at 57312/60000 samples
# Looked at 57344/60000 samples
# Looked at 57376/60000 samples
# Looked at 57408/60000 samples
# Looked at 57440/60000 samples
# Looked at 57472/60000 samples
# Looked at 57504/60000 samples
# Looked at 57536/60000 samples
# Looked at 57568/60000 samples
# Looked at 57600/60000 samples
# Looked at 57632/60000 samples
# Looked at 57664/60000 samples
# Looked at 57696/60000 samples
# Looked at 57728/60000 samples
# Looked at 57760/60000 samples
# Looked at 57792/60000 samples
# Looked at 57824/60000 samples
# Looked at 57856/60000 samples
# Looked at 57888/60000 samples
# Looked at 57920/60000 samples
# Looked at 57952/60000 samples
# Looked at 57984/60000 samples
# Looked at 58016/60000 samples
# Looked at 58048/60000 samples
# Looked at 58080/60000 samples
# Looked at 58112/60000 samples
# Looked at 58144/60000 samples
# Looked at 58176/60000 samples
# Looked at 58208/60000 samples
# Looked at 58240/60000 samples
# Looked at 58272/60000 samples
# Looked at 58304/60000 samples
# Looked at 58336/60000 samples
# Looked at 58368/60000 samples
# Looked at 58400/60000 samples
# Looked at 58432/60000 samples
# Looked at 58464/60000 samples
# Looked at 58496/60000 samples
# Looked at 58528/60000 samples
# Looked at 58560/60000 samples
# Looked at 58592/60000 samples
# Looked at 58624/60000 samples
# Looked at 58656/60000 samples
# Looked at 58688/60000 samples
# Looked at 58720/60000 samples
# Looked at 58752/60000 samples
# Looked at 58784/60000 samples
# Looked at 58816/60000 samples
# Looked at 58848/60000 samples
# Looked at 58880/60000 samples
# Looked at 58912/60000 samples
# Looked at 58944/60000 samples
# Looked at 58976/60000 samples
# Looked at 59008/60000 samples
# Looked at 59040/60000 samples
# Looked at 59072/60000 samples
# Looked at 59104/60000 samples
# Looked at 59136/60000 samples
# Looked at 59168/60000 samples
# Looked at 59200/60000 samples
# Looked at 59232/60000 samples
# Looked at 59264/60000 samples
# Looked at 59296/60000 samples
# Looked at 59328/60000 samples
# Looked at 59360/60000 samples
# Looked at 59392/60000 samples
# Looked at 59424/60000 samples
# Looked at 59456/60000 samples
# Looked at 59488/60000 samples
# Looked at 59520/60000 samples
# Looked at 59552/60000 samples
# Looked at 59584/60000 samples
# Looked at 59616/60000 samples
# Looked at 59648/60000 samples
# Looked at 59680/60000 samples
# Looked at 59712/60000 samples
# Looked at 59744/60000 samples
# Looked at 59776/60000 samples
# Looked at 59808/60000 samples
# Looked at 59840/60000 samples
# Looked at 59872/60000 samples
# Looked at 59904/60000 samples
# Looked at 59936/60000 samples
# Looked at 59968/60000 samples
#
# Train loss: 0.5904 | Test loss: 0.5095, Test acc: 82.0387
# Epoch: 1
# -----
#
# Train loss: 0.4763 | Test loss: 0.4799, Test acc: 83.1969
# Epoch: 2
# -----
#
# Train loss: 0.4550 | Test loss: 0.4766, Test acc: 83.4265
# Train time on cpu: 37.266 seconds

# %% [markdown]
# ## 4. Make predictions and get Model 0 results

# %%
torch.manual_seed(42)

# Define a function to evaluate a model
def eval_model(model:torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               accuracy_fn):
  '''Returns a dictionary containing the results of model predicting on data_loader.'''
  loss, acc = 0, 0
  model.eval()
  with torch.inference_mode():
    for X, y in tqdm(data_loader):
      # Make predictions
      y_pred = model(X)

      # Accumulate the loss and acc values per batch
      loss += loss_fn(y_pred, y)
      acc += accuracy_fn(y_true=y,
                         y_pred=y_pred.argmax(dim=1))

    # Scale loss and acc to find the average loss/acc per batch
    loss /= len(data_loader)
    acc /= len(data_loader)

  return {'model_name': model.__class__.__name__, # only works when model was created with a class
          'model_loss': loss.item(),
          'model_acc': acc}

# Create model 0 results on test dataset
model_0_results = eval_model(model=model_0,
                             data_loader=test_dataloader,
                             loss_fn=loss_fn,
                             accuracy_fn=accuracy_fn)
model_0_results
# Out:
#   0%|          | 0/313 [00:00<?, ?it/s]
# {'model_name': 'FashionMNISTModelV0',
#  'model_loss': 0.47663894295692444,
#  'model_acc': 83.42651757188499}

# %% [markdown]
# ## 5. Setup device agnostic-code (for using a GPU if there is one)

# %%
import torch

# Setup device agnostic-code
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# ## 6. Model 1: Building a better model with non-linearity
#
# We learned about the power of non-linearity in notebook 02

# %%
# Create a model with non-linear and linear layers
class FashionMNISTModelV1(nn.Module):
  def __init__(self,
               input_shape: int,
               hidden_units: int,
               output_shape: int):
    super().__init__()
    self.layer_stack = nn.Sequential(
        nn.Flatten(), # flatten inputs into a single vector
        nn.Linear(in_features=input_shape,
                  out_features=hidden_units),
        nn.ReLU(),
        nn.Linear(in_features=hidden_units,
                  out_features=output_shape),
        nn.ReLU()
    )

  def forward(self, x: torch.Tensor):
    return self.layer_stack(x)

# %%
# Create an instance of model_1
torch.manual_seed(42)
model_1 = FashionMNISTModelV1(input_shape=784,
                              hidden_units=10,
                              output_shape=len(class_names)).to(device) # send to GPU if available
next(model_1.parameters()).device
# Out:
# device(type='cpu')

# %% [markdown]
# ### 6.1 Setup loss, optimizer and evaluation metrics

# %%
# Define an accuracy function
def accuracy_fn(y_true, y_pred):
    """Calculates accuracy between truth labels and predictions.

    Args:
        y_true (torch.Tensor): Truth labels for predictions.
        y_pred (torch.Tensor): Predictions to be compared to predictions.

    Returns:
        [torch.float]: Accuracy value between y_true and y_pred, e.g. 78.45
    """
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct / len(y_pred)) * 100
    return acc

# Define loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params = model_1.parameters(),
                            lr = 0.1)

# %% [markdown]
# ### 6.2 Functionizing training and evaluation/testing loops
#
# Let's create a function for:
# * training loop - `train_step()`
# * testing loop - `test_step()`

# %%
# Define a training step to train the model
def train_step(model: torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               accuracy_fn,
               device: torch.device = device):
  '''Performs a training step with model trying to learn on data_loader.'''
  train_loss, train_acc = 0, 0

  # Put model into training mode
  model.train()

  # Add a loop to loop through the training batches
  for batch, (X, y) in enumerate(data_loader):
    # Put data on target device
    X, y = X.to(device), y.to(device)

    # 1. Forward pass (outputs the raw logits from the model)
    y_pred = model(X)

    # 2. Calculate loss and accuracy(per batch)
    loss = loss_fn(y_pred, y)
    train_loss += loss # accumulate train loss
    train_acc += accuracy_fn(y_true=y,
                             y_pred=y_pred.argmax(dim=1)) # go from logits -> prediction labels

    # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. Loss backward
    loss.backward()

    # 5. Optimizer step
    optimizer.step()

  # Divide total train loss and acc by length of train dataloader
  train_loss /= len(data_loader)
  train_acc /= len(data_loader)
  print(f'Train loss: {train_loss:.5f} | Train acc: {train_acc:.2f}%')

# %%
# Define a testing step to test the model
def test_step(model: torch.nn.Module,
              data_loader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              accuracy_fn,
              device: torch.device = device):
  '''Performs a testing loop step on model going over data_loader.'''
  test_loss, test_acc = 0, 0

  # Put the model in eval mode
  model.eval()

  # Turn on inference mode context manager
  with torch.inference_mode():
    for X, y in data_loader:
      # Send the data to the target device
      X, y = X.to(device), y.to(device)

      # 1. Forward pass (outputs raw logits)
      test_pred = model(X)

      # 2. Calculate the loss
      test_loss += loss_fn(test_pred, y)
      test_acc += accuracy_fn(y_true=y,
                              y_pred=test_pred.argmax(dim=1))

    # Adjust metrics and print out
    test_loss /= len(data_loader)
    test_acc /= len(data_loader)
    print(f'Test loss: {test_loss:.5f} | Test acc: {test_acc:.2f}%\n')

# %%
torch.manual_seed(42)

# Measure time
from timeit import default_timer as timer
train_time_start_on_gpu = timer()

# Set epochs
epochs = 3

# Create a optimization and evaluation loop using train_step() and test_step()
for epoch in tqdm(range(epochs)):
  print(f'Epoch: {epoch}\n--------')
  train_step(model=model_1,
             data_loader=train_dataloader,
             loss_fn=loss_fn,
             optimizer=optimizer,
             accuracy_fn=accuracy_fn,
             device=device)
  test_step(model=model_1,
            data_loader=test_dataloader,
            loss_fn=loss_fn,
            accuracy_fn=accuracy_fn,
            device=device)

  train_time_end_on_gpu = timer()
  total_train_time_model_1 = print_train_time(start=train_time_start_on_gpu,
                                              end=train_time_end_on_gpu,
                                              device=device)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# --------
# Train loss: 1.09199 | Train acc: 61.34%
# Test loss: 0.95636 | Test acc: 65.00%
#
# Train time on cpu: 12.066 seconds
# Epoch: 1
# --------
# Train loss: 0.78101 | Train acc: 71.93%
# Test loss: 0.72227 | Test acc: 73.91%
#
# Train time on cpu: 24.469 seconds
# Epoch: 2
# --------
# Train loss: 0.67027 | Train acc: 75.94%
# Test loss: 0.68500 | Test acc: 75.02%
#
# Train time on cpu: 38.054 seconds

# %% [markdown]
# **Note:** Sometimes, depending on your data/hardware you might find that your model trains faster on CPU than GPU.
#
# Why is this?
#
# 1. It could be that the overhead for copying data/model to and from the GPU outweights the compute benefits offered by the GPU.
# 2. The hardware you're using has a better CPU in terms compute capability than the GPU.
#
# For more on how to make your models compute faster, see here: https://horace.io/brrr_intro.html

# %%
# Print the train time on CPU
total_train_time_model_0
# Out:
# 37.265628553999704

# %%
torch.manual_seed(42)

# Define a function to evaluate the model
def eval_model(model:torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               accuracy_fn,
               device=device):
  '''Returns a dictionary containing the results of model predicting on data_loader.'''
  loss, acc = 0, 0
  model.eval()
  with torch.inference_mode():
    for X, y in tqdm(data_loader):
      # Make device agnostic code
      X, y = X.to(device), y.to(device)

      # Make predictions
      y_pred = model(X)

      # Accumulate the loss and acc values per batch
      loss += loss_fn(y_pred, y)
      acc += accuracy_fn(y_true=y,
                         y_pred=y_pred.argmax(dim=1))

    # Scale loss and acc to find the average loss/acc per batch
    loss /= len(data_loader)
    acc /= len(data_loader)

  return {'model_name': model.__class__.__name__, # only works when model was created with a class
          'model_loss': loss.item(),
          'model_acc': acc}

# %%
# Get model_1 results dictionary
model_1_results = eval_model(model=model_1,
                             data_loader=test_dataloader,
                             loss_fn = loss_fn,
                             accuracy_fn=accuracy_fn,
                             device=device)
model_1_results
# Out:
#   0%|          | 0/313 [00:00<?, ?it/s]
# {'model_name': 'FashionMNISTModelV1',
#  'model_loss': 0.6850009560585022,
#  'model_acc': 75.01996805111821}

# %%
# Print the model 0 results
model_0_results
# Out:
# {'model_name': 'FashionMNISTModelV0',
#  'model_loss': 0.47663894295692444,
#  'model_acc': 83.42651757188499}

# %% [markdown]
# ## Model 2: Building a Convolutional Neural Network (CNN)
#
# CNN's are also known as ConvNets.
#
# CNN's are known for their capabilities to find patterns in visual data.
#
# To find out what's happening inside a CNN, see this website: https://poloclub.github.io/cnn-explainer/

# %%
# Create a convolutional neural network
class FashionMNISTModelV2(nn.Module):
  '''
  Model architecture that replicates the TinyVGG
  model from the CNN explainer website.
  '''
  def __init__(self, input_shape:int, hidden_units:int, output_shape:int):
    super().__init__()
    self.conv_block_1 = nn.Sequential(
        nn.Conv2d(in_channels=input_shape,
                  out_channels=hidden_units,
                  kernel_size=3,
                  stride=1,
                  padding=1), # values we can set ourselves in our NN's are hyperparameters
        nn.ReLU(),
        nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  stride=1,
                  padding=1),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2)

    )
    self.conv_block_2 = nn.Sequential(
        nn.Conv2d(in_channels=hidden_units, \
                  out_channels=hidden_units,
                  kernel_size=3,
                  stride=1,
                  padding=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  stride=1,
                  padding=1),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2)
    )
    self.classifier = nn.Sequential(
        nn.Flatten(),
        nn.Linear(in_features=hidden_units*7*7,
                  out_features=output_shape)

    )

  def forward(self, x):
    x = self.conv_block_1(x)
    # print(f'Output shape of conv_block_1: {x.shape}')
    x = self.conv_block_2(x)
    # print(f'Output shape of conv_block_2: {x.shape}')
    x = self.classifier(x)
    # print(f'Output shape of classifier: {x.shape}')
    return x

# %%
# Initialize model_2 as a CNN
torch.manual_seed(42)
model_2 = FashionMNISTModelV2(input_shape=1,
                              hidden_units=10,
                              output_shape=len(class_names)).to(device)

# %%
# Define a random image tensor
rand_image_tensor = torch.randn(size=(1, 28, 28))
print(f'Shape of random image tensor: {rand_image_tensor.shape}')
# Out:
# Shape of random image tensor: torch.Size([1, 28, 28])

# %%
# Pass image through model
model_2(rand_image_tensor.unsqueeze(0).to(device))
# Out:
# tensor([[ 0.0366, -0.0940,  0.0686, -0.0485,  0.0068,  0.0290,  0.0132,  0.0084,
#          -0.0030, -0.0185]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ### 7.1 Stepping through `nn.Conv2d()`

# %%
torch.manual_seed(42)

# Create a batch of images
images = torch.randn(size=(32, 3, 64, 64))
test_image = images[0]

# Print out the image batch shape, single image shape, and test image array
print(f'Image batch shape: {images.shape}')
print(f'Single image shape: {test_image.shape}')
print(f'Test image:\n {test_image}')
# Out:
# Image batch shape: torch.Size([32, 3, 64, 64])
# Single image shape: torch.Size([3, 64, 64])
# Test image:
#  tensor([[[ 1.9269,  1.4873,  0.9007,  ...,  1.8446, -1.1845,  1.3835],
#          [ 1.4451,  0.8564,  2.2181,  ...,  0.3399,  0.7200,  0.4114],
#          [ 1.9312,  1.0119, -1.4364,  ..., -0.5558,  0.7043,  0.7099],
#          ...,
#          [-0.5610, -0.4830,  0.4770,  ..., -0.2713, -0.9537, -0.6737],
#          [ 0.3076, -0.1277,  0.0366,  ..., -2.0060,  0.2824, -0.8111],
#          [-1.5486,  0.0485, -0.7712,  ..., -0.1403,  0.9416, -0.0118]],
#
#         [[-0.5197,  1.8524,  1.8365,  ...,  0.8935, -1.5114, -0.8515],
#          [ 2.0818,  1.0677, -1.4277,  ...,  1.6612, -2.6223, -0.4319],
#          [-0.1010, -0.4388, -1.9775,  ...,  0.2106,  0.2536, -0.7318],
#          ...,
#          [ 0.2779,  0.7342, -0.3736,  ..., -0.4601,  0.1815,  0.1850],
#          [ 0.7205, -0.2833,  0.0937,  ..., -0.1002, -2.3609,  2.2465],
#          [-1.3242, -0.1973,  0.2920,  ...,  0.5409,  0.6940,  1.8563]],
#
#         [[-0.7978,  1.0261,  1.1465,  ...,  1.2134,  0.9354, -0.0780],
#          [-1.4647, -1.9571,  0.1017,  ..., -1.9986, -0.7409,  0.7011],
#          [-1.3938,  0.8466, -1.7191,  ..., -1.1867,  0.1320,  0.3407],
#          ...,
#          [ 0.8206, -0.3745,  1.2499,  ..., -0.0676,  0.0385,  0.6335],
#          [-0.5589, -0.3393,  0.2347,  ...,  2.1181,  2.4569,  1.3083],
#          [-0.4092,  1.5199,  0.2401,  ..., -0.2558,  0.7870,  0.9924]]])

# %%
torch.manual_seed(42)
# Create a single conv2d layer
conv_layer = nn.Conv2d(in_channels=3,
                       out_channels=10,
                       kernel_size=3,
                       stride=1,
                       padding=1)

# Pass the data through the convolutional layer
conv_output = conv_layer(test_image)
conv_output.shape
# Out:
# torch.Size([10, 64, 64])

# %% [markdown]
# ### 7.2 Stepping through `nn.MaxPool2d()`

# %%
# Print out original image shape without unsqeezed dimension
print(f'Test image original shape: {test_image.shape}')
print(f'Test image with unsqueezed dimension: {test_image.unsqueeze(0).shape}')

# Create a sample nn.MaxPool2d layer
max_pool_layer = nn.MaxPool2d(kernel_size=2)

# Pass data through just the conv_layer
test_image_through_conv = conv_layer(test_image.unsqueeze(dim=0))
print(f'Shape after going through conv_layer(): {test_image_through_conv.shape}')

# Pass data through the max pool layer
test_image_through_conv_and_max_pool = max_pool_layer(test_image_through_conv)
print(f'Shape after going through conv_layer() and max_pool_layer()" {test_image_through_conv_and_max_pool.shape}')
# Out:
# Test image original shape: torch.Size([3, 64, 64])
# Test image with unsqueezed dimension: torch.Size([1, 3, 64, 64])
# Shape after going through conv_layer(): torch.Size([1, 10, 64, 64])
# Shape after going through conv_layer() and max_pool_layer()" torch.Size([1, 10, 32, 32])

# %%
torch.manual_seed(42)
# Create a random tensor with a similar number of dimensions to our images
random_tensor = torch.randn(size=(1, 1, 2, 2))
print(f'Random tensor:\n {random_tensor}')
print(f'Random tensor shape: {random_tensor.shape}')

# Create a max pool layer
max_pool_layer = nn.MaxPool2d(kernel_size=2)

# Pass the random tensor through the max pool layer
max_pool_tensor = max_pool_layer(random_tensor)
print(f'\nMax pool tensor:\n {max_pool_tensor}')
print(f'Max pool tensor shape: {max_pool_tensor.shape}')
# Out:
# Random tensor:
#  tensor([[[[0.3367, 0.1288],
#           [0.2345, 0.2303]]]])
# Random tensor shape: torch.Size([1, 1, 2, 2])
#
# Max pool tensor:
#  tensor([[[[0.3367]]]])
# Max pool tensor shape: torch.Size([1, 1, 1, 1])

# %% [markdown]
# ### 7.3 Setup a loss function and optimizer for `model_2`

# %%
# Setup loss function/eval metrics/optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params = model_2.parameters(),
                            lr=0.1)

# %%
# Print out the parameters of model 2 and all its respective values
model_2.state_dict()
# Out:
# OrderedDict([('conv_block_1.0.weight',
#               tensor([[[[ 0.2548,  0.2767, -0.0781],
#                         [ 0.3062, -0.0730,  0.0673],
#                         [-0.1623,  0.1958,  0.2938]]],
#
#
#                       [[[-0.2445,  0.2897,  0.0624],
#                         [ 0.2463,  0.0451,  0.1607],
#                         [-0.0471,  0.2570,  0.0493]]],
#
#
#                       [[[-0.1556,  0.0850, -0.1536],
#                         [-0.0391, -0.1354,  0.2211],
#                         [-0.2631, -0.1537, -0.0941]]],
#
#
#                       [[[-0.2004,  0.0315, -0.3292],
#                         [ 0.3010, -0.2832,  0.2573],
#                         [ 0.0555, -0.1082,  0.2060]]],
#
#
#                       [[[ 0.0520,  0.2693,  0.0364],
#                         [-0.1051,  0.0896, -0.0904],
#                         [ 0.1403,  0.2976,  0.1927]]],
#
#
#                       [[[-0.1457,  0.1924,  0.0596],
#                         [ 0.1693, -0.2032, -0.3300],
#                         [-0.1288, -0.2557,  0.2735]]],
#
#
#                       [[[ 0.0960,  0.1381,  0.1054],
#                         [-0.0058,  0.2609, -0.2368],
#                         [ 0.0210, -0.2275,  0.1028]]],
#
#
#                       [[[-0.1148,  0.1021, -0.0694],
#                         [ 0.2765, -0.1976, -0.1988],
#                         [-0.1988,  0.2998,  0.1111]]],
#
#
#                       [[[ 0.3208, -0.2751, -0.3306],
#                         [-0.2608, -0.2242,  0.1350],
#                         [ 0.1194,  0.2770, -0.1721]]],
#
#
#                       [[[-0.2272,  0.1769, -0.1347],
#                         [ 0.2023, -0.0791,  0.1907],
#                         [-0.2590, -0.1682,  0.1016]]]])),
#              ('conv_block_1.0.bias',
#               tensor([ 0.0705, -0.0850,  0.1987,  0.2266, -0.2417, -0.1780,  0.3052, -0.1125,
#                       -0.1182, -0.3225])),
#              ('conv_block_1.2.weight',
#               tensor([[[[-0.0604,  0.0263, -0.0139],
#                         [-0.0765,  0.0025, -0.0720],
#                         [-0.0894, -0.0580, -0.0923]],
#
#                        [[-0.0671,  0.1054,  0.0199],
#                         [ 0.0325, -0.0983, -0.0692],
#                         [-0.0351,  0.0165, -0.0928]],
#
#                        [[-0.0454, -0.0631,  0.0003],
#                         [-0.0392, -0.0073, -0.0714],
#                         [-0.0724, -0.0615, -0.0361]],
#
#                        [[-0.0832,  0.0884, -0.0209],
#                         [ 0.0907,  0.0328, -0.0893],
#                         [ 0.0729, -0.0290, -0.0404]],
#
#                        [[-0.0875, -0.1048,  0.0302],
#                         [-0.0230,  0.0410, -0.0865],
#                         [ 0.0783, -0.0774, -0.0182]],
#
#                        [[ 0.0220,  0.0544,  0.0851],
#                         [ 0.0960, -0.0836,  0.0265],
#                         [-0.0453, -0.0116, -0.0789]],
#
#                        [[ 0.0960, -0.0774,  0.0563],
#                         [ 0.0370,  0.0343, -0.0570],
#                         [ 0.0958,  0.0232,  0.0136]],
#
#                        [[-0.0929,  0.0442, -0.0158],
#                         [-0.0483,  0.0905,  0.0235],
#                         [-0.0583, -0.0534, -0.0050]],
#
#                        [[ 0.0589, -0.0269, -0.0601],
#                         [-0.0361, -0.0787,  0.0376],
#                         [ 0.0816, -0.0992,  0.0245]],
#
#                        [[ 0.0545,  0.0191, -0.0375],
#                         [ 0.0550,  0.0554,  0.0394],
#                         [-0.0185, -0.0279,  0.0113]]],
#
#
#                       [[[-0.0186, -0.0314,  0.0674],
#                         [ 0.0906, -0.0104, -0.0236],
#                         [ 0.0015, -0.0063,  0.0253]],
#
#                        [[ 0.0295, -0.0957, -0.0389],
#                         [ 0.0888,  0.0411, -0.0052],
#                         [-0.0636, -0.0645, -0.0944]],
#
#                        [[-0.0344,  0.0356,  0.0672],
#                         [ 0.0487, -0.0932, -0.0634],
#                         [-0.0166,  0.1020,  0.0152]],
#
#                        [[-0.0273,  0.0436, -0.0401],
#                         [-0.0682,  0.0769, -0.0479],
#                         [-0.0211, -0.1049,  0.0705]],
#
#                        [[ 0.0799,  0.0384, -0.0735],
#                         [-0.1040, -0.0856,  0.0786],
#                         [ 0.0506,  0.0887,  0.0552]],
#
#                        [[ 0.0267, -0.0010, -0.0802],
#                         [-0.0903, -0.0986,  0.0432],
#                         [-0.0518, -0.0212, -0.0607]],
#
#                        [[-0.0192, -0.0742, -0.0689],
#                         [ 0.0350, -0.0313,  0.0651],
#                         [-0.0338, -0.0773, -0.0186]],
#
#                        [[-0.0511, -0.0322, -0.1003],
#                         [ 0.0590, -0.0734,  0.0530],
#                         [ 0.0478,  0.0753, -0.0809]],
#
#                        [[ 0.0758, -0.0498,  0.0391],
#                         [ 0.0990, -0.0149, -0.0008],
#                         [-0.0243, -0.0880,  0.0506]],
#
#                        [[-0.1046,  0.0654,  0.0789],
#                         [ 0.0997, -0.0249, -0.0866],
#                         [ 0.0237,  0.0582, -0.1049]]],
#
#
#                       [[[-0.0239, -0.0632, -0.0092],
#                         [-0.0519, -0.0431, -0.0335],
#                         [-0.1002,  0.0865,  0.0884]],
#
#                        [[-0.0165, -0.0120, -0.0430],
#                         [-0.0952, -0.1026,  0.0392],
#                         [-0.0579, -0.0678, -0.0082]],
#
#                        [[-0.0351, -0.0341,  0.0034],
#                         [-0.0224, -0.0363, -0.0505],
#                         [-0.0858,  0.0884, -0.0422]],
#
#                        [[ 0.0279, -0.0366,  0.0086],
#                         [ 0.0983,  0.0486, -0.0913],
#                         [ 0.0418,  0.1001,  0.0277]],
#
#                        [[ 0.0707,  0.1039, -0.0162],
#                         [ 0.0219, -0.0733, -0.0217],
#                         [ 0.0781,  0.0540, -0.0667]],
#
#                        [[-0.0845, -0.0720, -0.1040],
#                         [-0.0813, -0.0261,  0.0711],
#                         [ 0.0176, -0.0802, -0.0846]],
#
#                        [[ 0.0524, -0.0784, -0.0130],
#                         [ 0.0506, -0.0488, -0.0115],
#                         [-0.0092, -0.0249, -0.0534]],
#
#                        [[-0.0940, -0.0852, -0.0564],
#                         [ 0.1018, -0.0509, -0.0708],
#                         [ 0.0256,  0.0291,  0.0578]],
#
#                        [[ 0.0801,  0.0587, -0.1045],
#                         [ 0.0093,  0.0639, -0.0097],
#                         [-0.0621,  0.1005, -0.0394]],
#
#                        [[-0.0600, -0.0950,  0.0047],
#                         [ 0.0467,  0.0233,  0.0208],
#                         [-0.0799, -0.0984,  0.0019]]],
#
#
#                       [[[ 0.0961,  0.0608, -0.0614],
#                         [-0.0137, -0.0777, -0.0509],
#                         [ 0.0191,  0.0574,  0.0873]],
#
#                        [[-0.0968,  0.0705, -0.0743],
#                         [ 0.0395,  0.0892,  0.0015],
#                         [ 0.0959, -0.0898, -0.0403]],
#
#                        [[ 0.0615, -0.0230, -0.0216],
#                         [-0.0439,  0.0727,  0.0517],
#                         [ 0.0338, -0.0592, -0.0856]],
#
#                        [[ 0.0114,  0.0312, -0.0487],
#                         [-0.0295,  0.0712,  0.0084],
#                         [ 0.0048, -0.0259, -0.0955]],
#
#                        [[-0.0991, -0.0504, -0.0536],
#                         [ 0.0328, -0.0307, -0.0412],
#                         [ 0.1005,  0.0367,  0.0751]],
#
#                        [[-0.0510, -0.0431,  0.0387],
#                         [-0.0702, -0.0689, -0.0051],
#                         [-0.0386, -0.0790,  0.0625]],
#
#                        [[ 0.0848,  0.0171, -0.0184],
#                         [-0.0976, -0.0384,  0.0268],
#                         [ 0.0497, -0.0133, -0.0417]],
#
#                        [[ 0.0587, -0.0839,  0.0666],
#                         [-0.0409,  0.0016, -0.0208],
#                         [ 0.0128, -0.0319,  0.0766]],
#
#                        [[-0.0027,  0.0823,  0.1013],
#                         [-0.0514, -0.0769,  0.0846],
#                         [ 0.0826, -0.0805, -0.0081]],
#
#                        [[-0.1039, -0.0863,  0.0204],
#                         [ 0.0280,  0.0223, -0.0287],
#                         [ 0.0972,  0.0151, -0.0622]]],
#
#
#                       [[[-0.0060,  0.0253,  0.0369],
#                         [-0.0745,  0.0395, -0.0539],
#                         [-0.0876, -0.0576,  0.1017]],
#
#                        [[ 0.0901,  0.0944,  0.0619],
#                         [ 0.0796, -0.0141, -0.0580],
#                         [ 0.0527, -0.0546, -0.0711]],
#
#                        [[-0.0337,  0.0221,  0.0543],
#                         [-0.0409, -0.0620,  0.0142],
#                         [-0.0621, -0.0686,  0.0549]],
#
#                        [[-0.0177,  0.0963,  0.1025],
#                         [ 0.0315,  0.0363,  0.0243],
#                         [ 0.0017, -0.0077,  0.0014]],
#
#                        [[ 0.0394,  0.0980, -0.0273],
#                         [-0.0446, -0.0255, -0.0509],
#                         [ 0.0179,  0.0787,  0.0824]],
#
#                        [[ 0.0484, -0.0776, -0.0566],
#                         [-0.0232, -0.0194,  0.0087],
#                         [-0.0968,  0.0328, -0.0804]],
#
#                        [[-0.0667, -0.0876,  0.0918],
#                         [-0.0998,  0.0795, -0.0035],
#                         [-0.0123,  0.0659, -0.0097]],
#
#                        [[ 0.0661,  0.0762, -0.0915],
#                         [ 0.0406,  0.0199,  0.0227],
#                         [ 0.0154,  0.0288, -0.0507]],
#
#                        [[-0.0135,  0.1002,  0.0708],
#                         [-0.0040, -0.0991,  0.0046],
#                         [-0.0718,  0.0857, -0.0640]],
#
#                        [[-0.0076, -0.0234,  0.0188],
#                         [ 0.0992,  0.0100,  0.0610],
#                         [ 0.0818,  0.0851, -0.0364]]],
#
#
#                       [[[-0.0236,  0.0508, -0.0288],
#                         [ 0.0494, -0.0230, -0.0715],
#                         [ 0.0429,  0.0162,  0.0470]],
#
#                        [[ 0.1047,  0.0720,  0.0999],
#                         [ 0.0056, -0.0907, -0.0739],
#                         [-0.0655, -0.0929, -0.0528]],
#
#                        [[-0.0970, -0.0973, -0.0630],
#                         [-0.1039, -0.0647,  0.0402],
#                         [ 0.0879, -0.0314, -0.0307]],
#
#                        [[ 0.0563, -0.0520, -0.0498],
#                         [ 0.0649, -0.0918,  0.0129],
#                         [ 0.0931,  0.0181,  0.0287]],
#
#                        [[-0.0614, -0.0015,  0.0058],
#                         [ 0.0259,  0.0410,  0.0916],
#                         [-0.0805,  0.0032, -0.0527]],
#
#                        [[-0.0834, -0.0084, -0.0928],
#                         [ 0.0736,  0.0122, -0.0568],
#                         [ 0.0551, -0.0998, -0.0408]],
#
#                        [[-0.0205, -0.0896, -0.0670],
#                         [-0.0172,  0.0800,  0.1018],
#                         [ 0.0671, -0.0629, -0.0690]],
#
#                        [[ 0.0920,  0.0373,  0.0028],
#                         [ 0.0143, -0.0847, -0.0352],
#                         [ 0.1015, -0.0260, -0.0053]],
#
#                        [[-0.0875, -0.0590, -0.0022],
#                         [-0.0655, -0.0131,  0.0429],
#                         [-0.1031,  0.0313, -0.0697]],
#
#                        [[-0.0514,  0.0405,  0.0838],
#                         [-0.0288, -0.0433, -0.0953],
#                         [-0.0544, -0.0923, -0.0241]]],
#
#
#                       [[[ 0.0215, -0.0988,  0.0920],
#                         [ 0.0661, -0.1032, -0.0503],
#                         [ 0.0344, -0.0217, -0.0115]],
#
#                        [[-0.0476,  0.0847, -0.0589],
#                         [ 0.0874,  0.0068,  0.0212],
#                         [ 0.0822, -0.0174, -0.0600]],
#
#                        [[-0.0170,  0.0855, -0.0782],
#                         [ 0.0239, -0.1036,  0.0553],
#                         [ 0.0389,  0.0045,  0.0452]],
#
#                        [[ 0.0001,  0.0583, -0.0834],
#                         [-0.0155,  0.0468,  0.1050],
#                         [ 0.0537, -0.0767,  0.0811]],
#
#                        [[-0.0235, -0.0225, -0.0958],
#                         [-0.0166,  0.0746,  0.0147],
#                         [-0.0614,  0.0324, -0.0338]],
#
#                        [[ 0.0962, -0.0915, -0.0333],
#                         [-0.1018, -0.0415,  0.0332],
#                         [ 0.1015,  0.0177,  0.1033]],
#
#                        [[ 0.0206,  0.0609,  0.0845],
#                         [ 0.0881, -0.0590,  0.0969],
#                         [ 0.0639, -0.0493, -0.0503]],
#
#                        [[-0.0884,  0.0265, -0.0854],
#                         [ 0.0445,  0.0333, -0.0916],
#                         [ 0.0287, -0.0086,  0.0482]],
#
#                        [[ 0.0605, -0.1048,  0.0967],
#                         [ 0.0884,  0.0419, -0.0963],
#                         [-0.0377, -0.0305, -0.0271]],
#
#                        [[ 0.0594,  0.0383,  0.0835],
#                         [-0.0395,  0.0355,  0.0375],
#                         [-0.0878, -0.1022, -0.0547]]],
#
#
#                       [[[ 0.0722, -0.0992, -0.0918],
#                         [ 0.0591,  0.0569,  0.0867],
#                         [-0.0796, -0.0771,  0.0541]],
#
#                        [[ 0.0917,  0.0631,  0.0165],
#                         [ 0.0347,  0.1000, -0.0680],
#                         [-0.0479,  0.0737, -0.0721]],
#
#                        [[-0.0581,  0.0769,  0.0333],
#                         [ 0.0341, -0.0447, -0.0015],
#                         [ 0.0965, -0.0633,  0.0008]],
#
#                        [[ 0.0501, -0.0728,  0.1024],
#                         [-0.0527, -0.0253, -0.0285],
#                         [-0.0687, -0.1034,  0.0594]],
#
#                        [[ 0.0280, -0.0987, -0.0678],
#                         [ 0.1042,  0.0403,  0.0423],
#                         [-0.0631, -0.0462, -0.0159]],
#
#                        [[-0.0193, -0.0722,  0.0087],
#                         [ 0.0105, -0.0133,  0.0146],
#                         [-0.0418,  0.0274,  0.0398]],
#
#                        [[-0.0555, -0.1045,  0.0552],
#                         [ 0.0251, -0.0536,  0.1016],
#                         [-0.0477,  0.0712,  0.0535]],
#
#                        [[-0.0884,  0.0680, -0.0969],
#                         [-0.0584, -0.0176, -0.0711],
#                         [ 0.1030, -0.0211,  0.0419]],
#
#                        [[-0.0941,  0.0607, -0.0328],
#                         [-0.0802,  0.0154,  0.0511],
#                         [ 0.0912, -0.0644, -0.0519]],
#
#                        [[ 0.0203,  0.0286,  0.0405],
#                         [ 0.0579, -0.0239,  0.0586],
#                         [ 0.0777, -0.0275,  0.0750]]],
#
#
#                       [[[ 0.0515,  0.0930, -0.0599],
#                         [-0.0521, -0.0305,  0.0053],
#                         [ 0.0633, -0.0602,  0.0528]],
#
#                        [[-0.0378,  0.0637, -0.0050],
#                         [-0.0923, -0.0580, -0.0763],
#                         [ 0.0523, -0.0707, -0.0088]],
#
#                        [[ 0.0227, -0.0578,  0.0304],
#                         [-0.1029, -0.0754, -0.0955],
#                         [-0.0319, -0.0384,  0.0151]],
#
#                        [[-0.0195,  0.0496,  0.0966],
#                         [ 0.0378, -0.0415, -0.0987],
#                         [ 0.0382, -0.0522,  0.0536]],
#
#                        [[ 0.0705,  0.0407,  0.0989],
#                         [ 0.1001,  0.0223, -0.0768],
#                         [ 0.0942, -0.0500, -0.0498]],
#
#                        [[ 0.0882,  0.0817,  0.0318],
#                         [ 0.0066, -0.0887, -0.0109],
#                         [ 0.1011,  0.0268,  0.0090]],
#
#                        [[-0.0219, -0.0368,  0.0628],
#                         [ 0.0065,  0.0686, -0.0187],
#                         [ 0.0461,  0.0435,  0.0168]],
#
#                        [[ 0.0662,  0.0661,  0.0977],
#                         [ 0.0810, -0.0270, -0.0892],
#                         [ 0.0193, -0.0009, -0.0275]],
#
#                        [[-0.0177,  0.0050,  0.0769],
#                         [ 0.0329, -0.0374, -0.0433],
#                         [-0.0261, -0.0407,  0.0948]],
#
#                        [[ 0.0558,  0.0952,  0.0003],
#                         [ 0.0213,  0.0366, -0.0998],
#                         [ 0.0094, -0.0071, -0.0591]]],
#
#
#                       [[[-0.0818,  0.0933,  0.0857],
#                         [ 0.0489,  0.1006, -0.0428],
#                         [-0.0182,  0.0399, -0.0174]],
#
#                        [[-0.0207, -0.0871,  0.0283],
#                         [-0.0637,  0.0038,  0.1028],
#                         [-0.0324, -0.0332,  0.0636]],
#
#                        [[-0.0388, -0.0091,  0.0984],
#                         [-0.0432, -0.0754, -0.0590],
#                         [-0.0292, -0.0500, -0.0547]],
#
#                        [[ 0.0426,  0.0179, -0.0337],
#                         [-0.0819, -0.0332, -0.0445],
#                         [-0.0343, -0.0951,  0.0227]],
#
#                        [[-0.0774, -0.0821, -0.0861],
#                         [ 0.0440, -0.0635, -0.0435],
#                         [ 0.0826,  0.0560,  0.0604]],
#
#                        [[-0.1001, -0.0756, -0.0398],
#                         [ 0.0871,  0.0108, -0.0788],
#                         [ 0.0007, -0.0819, -0.0231]],
#
#                        [[-0.0290,  0.0912,  0.0326],
#                         [-0.0184,  0.0178, -0.0304],
#                         [ 0.0414,  0.0417,  0.0283]],
#
#                        [[-0.0411,  0.0899, -0.0152],
#                         [-0.0410,  0.0660,  0.0859],
#                         [ 0.1049,  0.0312, -0.0359]],
#
#                        [[ 0.0535,  0.0904, -0.1034],
#                         [-0.0131, -0.0719,  0.0196],
#                         [ 0.0436, -0.0218, -0.0088]],
#
#                        [[ 0.0474, -0.0177, -0.0885],
#                         [ 0.0843, -0.0531, -0.0116],
#                         [ 0.0099, -0.0063, -0.0992]]]])),
#              ('conv_block_1.2.bias',
#               tensor([ 0.0484, -0.0479, -0.0547,  0.0252, -0.0550, -0.0487, -0.0355, -0.0396,
#                       -0.0440, -0.0284])),
#              ('conv_block_2.0.weight',
#               tensor([[[[ 2.7393e-02, -8.5299e-02, -6.3802e-02],
#                         [ 1.5381e-03,  1.4659e-02,  5.8217e-02],
#                         [-7.4044e-02,  3.3646e-02,  5.9914e-02]],
#
#                        [[ 5.8530e-02, -9.8180e-02, -4.0225e-02],
#                         [-9.0606e-02, -6.6704e-02,  5.8711e-02],
#                         [-1.5740e-02,  4.4769e-02, -6.1876e-02]],
#
#                        [[ 1.6018e-02, -6.3758e-02,  5.2693e-02],
#                         [-4.6104e-02, -2.6432e-02, -9.1456e-02],
#                         [ 3.4822e-04,  1.0008e-01,  5.1163e-02]],
#
#                        [[-5.6240e-02,  1.4176e-03, -1.1558e-02],
#                         [-8.4862e-02,  8.2650e-02,  1.6993e-03],
#                         [ 2.2199e-02, -4.2567e-02, -4.9323e-02]],
#
#                        [[ 1.7381e-02,  3.8971e-02,  2.3643e-02],
#                         [-5.0801e-02,  1.0234e-01, -1.5517e-02],
#                         [-6.4554e-02, -4.9301e-02,  1.0377e-01]],
#
#                        [[ 5.0766e-06, -1.4309e-02, -4.3867e-02],
#                         [-2.7633e-02, -8.8779e-02, -8.3767e-02],
#                         [ 6.1695e-02,  9.0172e-02,  1.0059e-01]],
#
#                        [[-7.6099e-02,  5.7012e-02, -6.5245e-02],
#                         [ 6.2883e-02,  7.6058e-02,  8.1573e-02],
#                         [ 7.5900e-02,  6.5941e-02,  2.0516e-03]],
#
#                        [[ 4.8434e-02, -3.7712e-02,  4.5899e-02],
#                         [-3.3879e-02, -1.7700e-03, -9.1746e-02],
#                         [-2.7562e-02, -5.5432e-02, -3.5557e-02]],
#
#                        [[-6.7313e-02, -9.4810e-02,  6.8639e-03],
#                         [ 6.8408e-02,  9.6001e-02,  6.1512e-02],
#                         [-5.4638e-02, -1.0425e-01,  3.9983e-02]],
#
#                        [[ 5.9062e-02, -9.0495e-02,  3.7798e-02],
#                         [ 8.9121e-02,  6.3853e-03, -6.3505e-02],
#                         [ 8.6423e-02,  4.5011e-02,  6.9802e-02]]],
#
#
#                       [[[-7.1287e-02,  6.1342e-02, -7.2002e-02],
#                         [ 1.0430e-01, -4.4662e-02,  6.3516e-02],
#
#                        [[-1.1527e-03, -7.4309e-02, -2.7927e-02],
#                         [-3.4129e-02,  6.5100e-02, -3.4478e-02],
#                         [-3.0360e-02, -7.4720e-02, -4.9646e-02]],
#
#                        [[ 5.7074e-02,  6.7914e-02,  1.5315e-02],
#                         [-3.9549e-02,  1.0124e-01,  2.0806e-02],
#                         [-4.0688e-02, -3.6535e-02, -1.4752e-02]],
#
#                        [[ 4.9974e-02,  3.8555e-02,  7.6418e-02],
#                         [-4.7494e-03,  8.7183e-02, -4.2816e-02],
#                         [-4.8547e-02, -3.8927e-02, -9.8896e-02]],
#
#                        [[-6.9195e-02, -9.5382e-02, -6.2294e-03],
#                         [ 9.9374e-04, -2.7358e-02, -7.2035e-02],
#                         [ 9.5637e-02, -3.4926e-02,  5.0233e-02]],
#
#                        [[ 7.3408e-02, -6.9291e-02, -1.3179e-02],
#                         [ 6.0923e-02,  1.0218e-01, -1.3299e-02],
#                         [ 7.6382e-02, -8.2732e-02, -6.8489e-02]],
#
#                        [[ 8.6682e-02, -9.9801e-03,  1.0414e-01],
#                         [ 7.6651e-03, -4.3714e-02,  1.0011e-01],
#                         [ 9.2179e-02,  9.7826e-03, -6.3900e-02]],
#
#                        [[-4.5639e-03, -5.0693e-02,  7.6810e-02],
#                         [ 4.8829e-03,  2.2191e-02,  6.3927e-02],
#                         [ 3.4916e-02, -6.5803e-02,  8.7566e-02]],
#
#                        [[ 6.4758e-02, -6.5073e-02,  7.9700e-02],
#                         [ 2.9905e-02, -2.0750e-02, -7.5385e-02],
#                         [-1.7490e-02, -1.0335e-01,  6.0163e-02]]],
#
#
#                       [[[ 7.6343e-02, -3.0347e-02,  9.7720e-02],
#                         [-3.9032e-02,  1.8051e-02, -7.3459e-02],
#                         [-4.4565e-03,  4.2610e-02,  4.5403e-02]],
#
#                        [[-3.5346e-03, -5.3154e-02,  7.3680e-02],
#                         [ 6.9788e-02,  1.6916e-02, -4.8475e-02],
#                         [ 2.2349e-02,  2.8186e-04,  9.6302e-02]],
#
#                        [[ 1.5621e-02,  8.1301e-03,  7.2057e-03],
#                         [ 5.6079e-02, -1.3024e-03,  9.0351e-02],
#                         [ 5.4917e-02, -7.9650e-02, -1.2063e-06]],
#
#                        [[-8.9472e-02, -8.0934e-02,  2.0480e-02],
#                         [ 2.3687e-02, -9.2246e-03,  1.0019e-01],
#                         [-5.6627e-02, -4.4176e-02, -1.6881e-02]],
#
#                        [[ 6.3911e-04, -8.9284e-03,  9.4909e-02],
#                         [-4.4519e-02, -5.5137e-02,  9.0599e-03],
#                         [ 7.9171e-02,  2.5019e-02,  5.6787e-02]],
#
#                        [[ 2.0406e-02,  8.9839e-02,  6.3311e-02],
#                         [ 7.5428e-02, -1.4198e-02, -8.7268e-02],
#                         [-5.0002e-02,  3.5910e-02,  7.3950e-02]],
#
#                        [[-4.1184e-02,  8.7218e-02,  1.5150e-02],
#                         [ 4.1869e-04,  4.1093e-03, -1.8623e-02],
#                         [ 9.8683e-02,  4.5784e-03,  6.4564e-02]],
#
#                        [[-8.8967e-02, -5.4309e-02,  1.1852e-02],
#                         [ 8.4169e-02,  5.0184e-02,  2.0076e-02],
#                         [-1.0414e-01,  1.9816e-03, -6.9581e-02]],
#
#                        [[-9.0006e-02,  1.4414e-02, -6.6693e-02],
#                         [ 9.5674e-02, -5.7294e-02,  3.3970e-02],
#                         [ 6.1871e-02, -8.1928e-02,  5.3946e-02]],
#
#                        [[-1.4114e-02,  5.4619e-02,  1.0201e-01],
#                         [-4.4922e-02, -4.5653e-02,  8.3753e-02],
#                         [ 1.1722e-02, -1.0513e-02,  7.9971e-02]]],
#
#
#                       [[[-5.0928e-02, -5.2047e-03,  7.2403e-02],
#                         [ 4.1195e-02, -6.8180e-02,  2.7398e-02],
#                         [-8.0368e-02, -5.7245e-02,  6.7779e-02]],
#
#                        [[-2.8093e-02, -5.3691e-02,  7.4717e-03],
#                         [ 2.5759e-02, -6.5524e-02, -7.1084e-02],
#                         [-1.0209e-01,  2.7236e-02, -6.8013e-02]],
#
#                        [[ 8.0331e-03, -2.3576e-02, -6.8923e-02],
#                         [-3.3636e-02, -8.1027e-02, -5.5797e-02],
#                         [-3.2857e-03, -9.0116e-02, -9.2447e-02]],
#
#                        [[ 7.8958e-02,  9.9188e-03, -4.6618e-02],
#                         [-3.5047e-03,  7.8168e-02, -8.7939e-02],
#                         [-5.5886e-02, -7.6226e-02, -7.6634e-03]],
#
#                        [[-3.6274e-03, -8.2146e-02,  7.3163e-02],
#                         [-8.0946e-02,  9.8414e-02, -7.2560e-02],
#                         [-1.4446e-02,  1.9710e-02, -4.6852e-02]],
#
#                        [[ 9.6939e-02, -7.2673e-02, -5.8427e-03],
#                         [-7.7398e-02,  2.9261e-02,  8.9871e-02],
#                         [ 9.7776e-02,  1.2514e-02, -5.2773e-02]],
#
#                        [[ 1.0244e-01,  7.8667e-03,  7.1317e-02],
#                         [-5.4751e-02, -4.8920e-02, -8.7504e-02],
#                         [ 9.6990e-02,  1.7486e-02, -7.5704e-02]],
#
#                        [[ 9.0535e-03, -4.5211e-02,  5.2659e-03],
#                         [ 3.4988e-02, -5.2308e-02,  1.8394e-02],
#                         [-6.6553e-02,  2.0312e-02, -1.0178e-01]],
#
#                        [[ 1.6797e-02,  1.0473e-01,  9.7094e-02],
#                         [ 3.8451e-02,  7.7563e-02,  1.0248e-01],
#                         [ 2.9870e-02,  3.5156e-02,  1.3707e-02]],
#
#                        [[ 9.3322e-02,  9.0551e-02, -4.9570e-02],
#                         [-4.3333e-03, -5.3110e-02,  3.7824e-02],
#                         [-1.0214e-01,  3.7301e-02, -2.8929e-02]]],
#
#
#                       [[[ 3.8227e-02,  3.2899e-02, -5.2454e-02],
#                         [ 5.4687e-02,  4.4762e-02, -8.9602e-02],
#                         [ 1.0517e-01,  9.0731e-02,  6.5584e-02]],
#
#                        [[-1.0699e-02,  3.7345e-02, -5.7028e-02],
#                         [-3.5818e-02,  4.9749e-02,  4.6925e-02],
#                         [ 4.1741e-02, -1.0053e-01,  8.7350e-02]],
#
#                        [[-4.4028e-02,  9.1223e-02,  8.6852e-02],
#                         [ 3.9070e-02,  1.0502e-01,  6.0528e-02],
#                         [ 6.1821e-02, -3.5794e-02,  9.7766e-02]],
#
#                        [[ 2.7627e-02,  6.2280e-02, -2.3834e-02],
#                         [ 7.6340e-02,  9.3509e-02, -8.0770e-02],
#                         [ 8.6415e-02, -6.9664e-02, -7.2571e-02]],
#
#                        [[-8.8089e-02,  3.0459e-02, -7.9144e-02],
#                         [-3.9680e-02, -5.2988e-02,  2.8172e-02],
#                         [-1.0349e-01, -4.8324e-02,  7.7112e-04]],
#
#                        [[ 9.4660e-03, -4.7605e-02,  3.7764e-02],
#                         [-6.9544e-02, -8.9270e-02, -1.4986e-02],
#                         [-5.6989e-02,  6.6443e-02, -7.2049e-02]],
#
#                        [[-8.8494e-03,  4.3782e-02, -9.2311e-02],
#                         [ 8.1599e-02, -4.7895e-02, -2.8684e-02],
#                         [-6.4480e-02, -3.9279e-02, -4.0645e-02]],
#
#                        [[-9.3801e-02,  3.6019e-02, -3.3768e-04],
#                         [ 1.0311e-01,  7.1117e-02,  9.1699e-02],
#                         [ 3.1014e-02,  5.5388e-02,  9.8704e-02]],
#
#                        [[ 8.6545e-02, -8.0996e-02, -2.3636e-02],
#                         [-1.0166e-01,  3.9877e-03, -3.7229e-02],
#                         [ 9.1486e-02,  1.6666e-02,  1.1601e-03]],
#
#                        [[-7.6248e-02, -8.2718e-02,  1.6594e-02],
#                         [-5.2376e-02, -4.8409e-02,  7.3938e-02],
#                         [-5.4952e-02, -4.6918e-02,  8.0934e-02]]]])),
#              ('conv_block_2.2.bias',
#               tensor([ 0.0412, -0.0599,  0.0319,  0.0531, -0.0936,  0.0197,  0.0241, -0.0041,
#                        0.1011, -0.0697])),
#              ('classifier.1.weight',
#               tensor([[ 0.0245, -0.0240, -0.0387,  ...,  0.0094, -0.0015, -0.0225],
#                       [ 0.0228,  0.0067, -0.0439,  ..., -0.0302,  0.0368,  0.0293],
#                       [ 0.0303,  0.0347, -0.0211,  ...,  0.0207, -0.0423, -0.0240],
#                       ...,
#                       [-0.0359, -0.0343,  0.0166,  ...,  0.0324,  0.0113, -0.0143],
#                       [-0.0294, -0.0316,  0.0251,  ..., -0.0056,  0.0300, -0.0396],
#                       [-0.0246, -0.0035, -0.0046,  ..., -0.0146, -0.0358,  0.0175]])),
#              ('classifier.1.bias',
#               tensor([ 0.0320, -0.0445,  0.0246, -0.0357, -0.0442,  0.0156, -0.0010, -0.0277,
#                        0.0404,  0.0037]))])

# %% [markdown]
# ### 7.4 Training and testing `model_2` using our training and test functions

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Measure time
from timeit import default_timer as timer
train_time_start_model_2 = timer()

# Train and test model
epochs = 3
for epoch in tqdm(range(epochs)):
  print(f'Epoch: {epoch}\n-----')
  train_step(model=model_2,
             data_loader=train_dataloader,
             loss_fn=loss_fn,
             optimizer=optimizer,
             accuracy_fn=accuracy_fn,
             device=device)
  test_step(model=model_2,
            data_loader=test_dataloader,
            loss_fn=loss_fn,
            accuracy_fn=accuracy_fn,
            device=device)

# Calculate the total training time
train_time_end_model_2 = timer()
total_train_time_model_2 = print_train_time(start=train_time_start_model_2,
                                            end=train_time_end_model_2,
                                            device=device)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# -----
# Train loss: 0.59518 | Train acc: 78.38%
# Test loss: 0.39500 | Test acc: 85.99%
#
# Epoch: 1
# -----
# Train loss: 0.36536 | Train acc: 86.90%
# Test loss: 0.35244 | Test acc: 86.91%
#
# Epoch: 2
# -----
# Train loss: 0.32588 | Train acc: 88.13%
# Test loss: 0.32719 | Test acc: 88.07%
#
# Train time on cpu: 183.798 seconds

# %%
# Get model_2 results
model_2_results = eval_model(
    model=model_2,
    data_loader=test_dataloader,
    loss_fn=loss_fn,
    accuracy_fn=accuracy_fn,
    device=device
)

# Print the model_2 results
model_2_results
# Out:
#   0%|          | 0/313 [00:00<?, ?it/s]
# {'model_name': 'FashionMNISTModelV2',
#  'model_loss': 0.32718968391418457,
#  'model_acc': 88.06908945686901}

# %% [markdown]
# ## 8. Compare model results and training time

# %%
import pandas as pd
# Make a table of model_0, model_1, and model_2 results
compare_results = pd.DataFrame([model_0_results,
                                model_1_results,
                                model_2_results])
compare_results
# Out:
#             model_name  model_loss  model_acc
# 0  FashionMNISTModelV0    0.476639  83.426518
# 1  FashionMNISTModelV1    0.685001  75.019968
# 2  FashionMNISTModelV2    0.327190  88.069089

# %%
# Add training time to results comparison
compare_results['training_time'] = [total_train_time_model_0,
                                    total_train_time_model_1,
                                    total_train_time_model_2]
compare_results
# Out:
#             model_name  model_loss  model_acc  training_time
# 0  FashionMNISTModelV0    0.476639  83.426518      37.265629
# 1  FashionMNISTModelV1    0.685001  75.019968      38.053584
# 2  FashionMNISTModelV2    0.327190  88.069089     183.797857

# %%
# Visualize our model results through a bar graph
compare_results.set_index('model_name')['model_acc'].plot(kind='barh')
plt.xlabel('accuracy (%)')
plt.ylabel('model')
# Out:
# Text(0, 0.5, 'model')

# %% [markdown]
# ## 9. Make and evaluate random predictions with best model

# %%
# Define a function to make predictions on data using a model
def make_predictions(model: torch.nn.Module,
                     data: list,
                     device: torch.device = device):
  pred_probs = []
  model.to(device)
  model.eval()
  with torch.inference_mode():
    for sample in data:
      # Prepare the sample (add a batch dimension and pass to target device)
      sample = torch.unsqueeze(sample, dim=0).to(device)

      # Forward pass (model outputs raw logits)
      pred_logit = model(sample)

      # Get prediction probability (logit -> prediction probability)
      pred_prob = torch.softmax(pred_logit.squeeze(), dim=0)

      # Get pred_prob off the GPU for further calculations
      pred_probs.append(pred_prob.cpu())

  # Stack the pred prob to turn list into a tensor
  return torch.stack(pred_probs)

# %%
# Get a random image, its label, and the image shape
img, label = test_data[0][:10]
print(f'Image shape: {img.shape}')
print(f'Image label: {label}')
# Out:
# Image shape: torch.Size([1, 28, 28])
# Image label: 9

# %%
import random
test_samples = []
test_labels = []
for sample, label in random.sample(list(test_data), k=9):
  test_samples.append(sample)
  test_labels.append(label)

# View the first sample's shape
print(f'Shape of first sample: {test_samples[0].shape}')
# Out:
# Shape of first sample: torch.Size([1, 28, 28])

# %%
# Display the first image in test_samples
plt.imshow(test_samples[0].squeeze(), cmap='gray')
plt.title(class_names[test_labels[0]])
# Out:
# Text(0.5, 1.0, 'Bag')

# %%
# Make predictions
pred_probs = make_predictions(model=model_2,
                              data=test_samples)

# View first two prediction probabilities
pred_probs[:2]
# Out:
# tensor([[3.4894e-03, 1.8397e-06, 2.7391e-03, 2.5703e-04, 2.2829e-03, 2.5308e-04,
#          3.9977e-04, 1.2232e-05, 9.9056e-01, 3.2952e-06],
#         [6.7809e-03, 1.3292e-03, 9.1497e-01, 7.4148e-04, 4.0289e-02, 1.3693e-04,
#          3.4456e-02, 2.8164e-05, 1.1147e-03, 1.5333e-04]])

# %%
# Convert prediction probabilities to labels
pred_classes = pred_probs.argmax(dim=1)
pred_classes
# Out:
# tensor([8, 2, 3, 0, 2, 3, 8, 7, 0])

# %%
# Print the calculated test labels
test_labels
# Out:
# [8, 2, 3, 6, 2, 0, 8, 7, 0]

# %%
# Plot predictions
plt.figure(figsize=(9, 9))
nrows = 3
ncols = 3
for i, sample in enumerate(test_samples):
  # Create subplot
  plt.subplot(nrows, ncols, i+1)

  # Plot the target image
  plt.imshow(sample.squeeze(), cmap='gray')

  # Find the prediction (in text form, e.g. 'Sandal')
  pred_label = class_names[pred_classes[i]]

  # Get the truth label (in text form)
  truth_label = class_names[test_labels[i]]

  # Create a title for the plot
  title_text = f'Pred: {pred_label} | Truth: {truth_label}'

  # Check for equality between pred and truth and change color of title text
  if pred_label == truth_label:
    plt.title(title_text, fontsize=10, c='g') # green text if prediction same as truth
  else:
    plt.title(title_text, fontsize=10, c='r')

  plt.axis(False)

# %% [markdown]
# ## 10. Making a confusion matrix for further prediction evaluation
#
# A confusion matrix is a fantastic way of evaluating your classification models visually
#
# 1. Make predictions with our trained model on the test dataset
# 2. Make a confusion matrix `torchmetrics.ConfusionMatrix` - https://torchmetrics.readthedocs.io/en/stable/classification/confusion_matrix.html
# 3. Plot the confusion matrix using `mlxtend.plotting.plot_confusion_matrix()` - https://rasbt.github.io/mlxtend/user_guide/plotting/plot_confusion_matrix/

# %%
# Import tqdm.auto
from tqdm.auto import tqdm

# 1. Make predictions with trained model
y_preds = []
model_2.eval()
with torch.inference_mode():
  for X, y in tqdm(test_dataloader, desc='Making predictions'):
    # Send the data and targets to target device
    X, y = X.to(device), y.to(device)
    # Do the forward pass
    y_logit = model_2(X)
    # Turn predictions from logits -> prediction probabilities -> prediction labels
    y_pred = torch.softmax(y_logit.squeeze(), dim=0).argmax(dim=1)
    # Put prediction on CPU for evaluation
    y_preds.append(y_pred.cpu())

  # Concatenate list of predictions into a tensor
  # print(y_preds)
  y_pred_tensor = torch.cat(y_preds)
  print(y_pred_tensor[:10])
# Out:
# Making predictions:   0%|          | 0/313 [00:00<?, ?it/s]
# tensor([9, 2, 1, 1, 6, 1, 4, 6, 5, 7])

# %%
# See if required packages are installed and if not, install them...
try:
  import torchmetrics, mlxtend
  print(f'mlxtend version: {mlxtend.__version__}')
  assert int(mlxtend.__version__.split('.')[1]) >= 19, 'mlxtend version should be 0.19.0 or higher'
except:
  # !pip install torchmetrics -U mlxtend
  import torchmetrics, mlxtend
  print(f'mixtend version: {mlxtend.__version__}')
# Out:
# mlxtend version: 0.24.0

# %%
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# 2. Setup confusion matrix instance and compare predictions to targets
confmat = ConfusionMatrix(task='multiclass', num_classes=len(class_names))
confmat_tensor = confmat(preds=y_pred_tensor,
                         target=test_data.targets)

# 3. Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat = confmat_tensor.numpy(),
    class_names=class_names,
    figsize=(10, 7)
)

# %%
# Print the confusion matrix tensor
confmat_tensor
# Out:
# tensor([[628,   5,  44,  79,  12,   1, 224,   0,   7,   0],
#         [  8, 895,   7,  68,  13,   0,   5,   0,   3,   1],
#         [  7,   1, 810,  13,  95,   0,  69,   0,   5,   0],
#         [ 25,  13,  25, 861,  36,   0,  34,   0,   4,   2],
#         [  5,   6, 117,  50, 712,   0, 106,   0,   4,   0],
#         [  6,   0,   9,  11,   0, 840,   4,  44,  66,  20],
#         [ 69,   7, 123,  64,  98,   0, 626,   0,  13,   0],
#         [  1,   1,   0,   1,   0,  33,   0, 877,  18,  69],
#         [  8,   2,  23,  17,   6,   7,  29,   7, 900,   1],
#         [  1,   0,   1,   2,   0,  20,   4,  71,  11, 890]])

# %% [markdown]
# ## 11. Save and load best performing model

# %%
from pathlib import Path

# Create model directory path
MODEL_PATH = Path('models')
MODEL_PATH.mkdir(parents=True,
                 exist_ok=True)

# Create model save
MODEL_NAME = '03_pytorch_computer_vision_model_2.pth'
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

MODEL_SAVE_PATH

# Save the model state dict
print(f'Saving model to: {MODEL_SAVE_PATH}')
torch.save(obj=model_2.state_dict(),
           f=MODEL_SAVE_PATH)
# Out:
# Saving model to: models/03_pytorch_computer_vision_model_2.pth

# %%
# Create a new instance
torch.manual_seed(42)

loaded_model_2 = FashionMNISTModelV2(input_shape=1,
                                     hidden_units=10,
                                     output_shape=len(class_names))

# Load in the save state_dict()
loaded_model_2.load_state_dict(torch.load(f=MODEL_SAVE_PATH))

# Send the model to the target device
loaded_model_2.to(device)
# Out:
# FashionMNISTModelV2(
#   (conv_block_1): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=490, out_features=10, bias=True)
#   )
# )

# %%
# Print the results of model_2
model_2_results
# Out:
# {'model_name': 'FashionMNISTModelV2',
#  'model_loss': 0.32718968391418457,
#  'model_acc': 88.06908945686901}

# %%
# Evaluate loaded model
torch.manual_seed(42)

loaded_model_2_results = eval_model(
    model=loaded_model_2,
    data_loader=test_dataloader,
    loss_fn=loss_fn,
    accuracy_fn=accuracy_fn
)

loaded_model_2_results
# Out:
#   0%|          | 0/313 [00:00<?, ?it/s]
# {'model_name': 'FashionMNISTModelV2',
#  'model_loss': 0.32718968391418457,
#  'model_acc': 88.06908945686901}

# %%
# Check if model results are close to each other
torch.isclose(torch.tensor(model_2_results['model_loss']),
              torch.tensor(loaded_model_2_results['model_loss']))
# Out:
# tensor(True)
